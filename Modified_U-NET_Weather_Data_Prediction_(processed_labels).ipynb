# %% [markdown]
# ## **Modified-Unet**
#
# The model in this code is inspired by the U-Net model proposed by Ronneberger et. al. with modifications to Depth, Regularization and Hyperparameters.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install h5py pyyaml
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (3.13)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.5)

# %%
# Importing the necessary libraries and API's

import numpy as np 
from numpy import asarray
import tensorflow as tf 
from tensorflow.keras.optimizers import Adam,RMSprop,SGD
import os
import shutil 
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg
from PIL import Image
import keras
from tensorflow.keras.models import Model, load_model
import tensorflow.keras.layers

# %%
# Creating variables for training and labels directory
data_directory = r'/content/drive/My Drive/weather_news'
training_dir = r'/content/drive/My Drive/weather_news/train_images'
label_dir = r'/content/drive/My Drive/weather_news/LabelboxAnnotations'

# %%
# converting directory images into a list
train_list = os.listdir(training_dir)
label_list = os.listdir(label_dir)

# %%
# checking the length of the training and label directory 
print(len(train_list))
print(len(label_list))
# Out:
# 1576
# 1648

# %%
# We see that the label_list has some unnecessary segmentation labels not matching with the images in the training directory and hence wee need to remove them before training 

unwanted = []
train = []
label = []

for x in train_list:
    train.append(x[0:8])
    
for x in label_list:
    label.append(x[0:8])
    
for x in label:
    if x not in train:
        unwanted.append(x)

for x in unwanted:
    x = x + ".png"
    label_list.remove(x)

print(len(unwanted))
print(len(label_list))
print(len(train_list))
# Out:
# 72
# 1576
# 1576

# %%
# Sanity check for the shape of the labels  

f = None
for i in range(1576):
    img = mpimg.imread(label_dir + "/" + label_list[i])
    if img.shape != (160,160,4):
        print("found")
        f = 1
if f is None:
    print("all good")
# Out:
# all good

# %%
# Sanity check for the shape of the training data

f = None
for i in range(1576):
    img = mpimg.imread(training_dir + "/" + train_list[i])
    if img.shape != (160,160,3):
        print("found")
        f = 1
        
if f is None:
    print("all good")
# Out:
# all good

# %%
# creating the numpy arrays for the images and the corresponding segmentation labels 

height , width = (160,160)
m = len(label_list)
X = np.zeros([m, height, width, 3])
Y_init = np.zeros([m, height, width, 4])

for i in range(m):
    X[i] = mpimg.imread(training_dir + "/" + train_list[i])
    Y_init[i] = mpimg.imread(label_dir + "/" + label_list[i])

# %%
# color_list is actually a dictionary that contains the pixel valus across the channels for the four segmentation colors. While carrying out training for the segmentation labels we need the labels 
# to be 1 or 0 across the channels .In order to do so we need to convert the color pixels into binary values before training and convert the predicted maps into corresponding color pixels after prediction.
# Hence we need the color_list dictionary to carry out such conversions.

color_list = {}

color_list['blue'] = (0.0117647061124444, 0.6078431606292725, 0.8980392217636108, 1.0)
color_list['yellow'] = (0.8941176533699036, 0.7686274647712708, 0.2549019753932953, 1.0)
color_list['green'] = (0.3803921639919281, 0.3803921639919281, 0.3803921639919281, 1.0)
color_list['purple'] = (0.5568627715110779, 0.1411764770746231, 0.6666666865348816, 1.0)
color_list['white'] = (1.0, 1.0, 1.0, 1.0)
color_list
# Out:
# {'blue': (0.0117647061124444, 0.6078431606292725, 0.8980392217636108, 1.0),
#  'green': (0.3803921639919281, 0.3803921639919281, 0.3803921639919281, 1.0),
#  'purple': (0.5568627715110779, 0.1411764770746231, 0.6666666865348816, 1.0),
#  'white': (1.0, 1.0, 1.0, 1.0),
#  'yellow': (0.8941176533699036, 0.7686274647712708, 0.2549019753932953, 1.0)}

# %%
# label_preprocess function converts the color segmentaion maaps into binary along the channels acros the height and width of the segmentation labels.
# If the segentation labels of your data are already in binary then you dont need to use this function.

def label_preprocess(Y_init,num_images,height,width,channels,color_list):
      
    Y = np.zeros([num_images,height,width,channels])

    for n in range(num_images):
        for i in range(height):
            for j in range(width):
                t = tuple(Y_init[n,i,j,:])
        
                if t == color_list['blue']:
                    Y[n,i,j,:] = np.array((1,0,0,0))
                elif t == color_list['yellow']:
                    Y[n,i,j,:] = np.array((0,1,0,0))
                elif t == color_list['green']:
                    Y[n,i,j,:] = np.array((0,0,1,0))
                elif t == color_list['white']:
                    Y[n,i,j,:] = np.array((1,1,1,1))
                elif t == color_list['purple']:
                    Y[n,i,j,:] = np.array((0,0,0,1))
                    
    return Y

# %%
# This function is used to predict the segmentation output for images 

def predictions(trained_model,test_dir,num_images,height,width,channels,color_list):
    
    y = np.zeros([num_images,height,width,channels])
    x = np.zeros([num_images,height,width,channels])
    
    for i in range(len(test_list)):
        x[i] = mpimg.imread(test_dir + '/' + test_list[i])
        y[i] = trained_model.predict(np.expand_dims(x[i], axis = 0))
    
    Y_final = prediction_postprocess(y,num_images,height,width,channels,color_list)
    
    for i in range(Y_final.shape[0]):
        plt.imshow(Y[i])
        plt.show()

# %%
# Before giving the final predicted map the image is processed to yield the segmentation in the four segmentation colors

def prediction_postprocess(trained_model,test_directory,num_images,height,width,channel,color_list):
    
    Y_pred = np.zeros([num_images,height,width,channel])
    Y_init_pred = np.zeros([num_images,height,width,channel])
    test_list = os.listdir(test_directory)
    axis_image = plt.figure(figsize = (100,100))
    t = 0

    
    for n in range(num_images):

      image = mpimg.imread(test_directory + '/' + test_list[n])
      Y_init_pred[n,:,:,:] = trained_model.predict(np.expand_dims(image, axis = 0))

      for i in range(height):
        for j in range(width):

          ch = np.argmax(Y_init_pred[n,i,j,:])

          if ch == 0:
            Y_pred[n,i,j,:] = np.array(color_list['blue'])
          elif ch == 1:
            Y_pred[n,i,j,:] = np.array(color_list['yellow'])
          elif ch == 2:
            Y_pred[n,i,j,:] = np.array(color_list['green'])
          elif ch == 3:
            Y_pred[n,i,j,:] = np.array(color_list['purple'])

      img = axis_image.add_subplot(num_images, 2,t+1, xticks = [], yticks = [])
      plt.imshow(np.squeeze(image))
      plt.savefig('/content/drive/My Drive/weather_news/model_unet_processed/Test_Predictions/Test_Image_Predictions_' + str(t+1))
      plt.show()

      img = axis_image.add_subplot(num_images, 2,t+2, xticks = [], yticks = [])
      plt.imshow(np.squeeze(Y_pred[n]))
      plt.savefig('/content/drive/My Drive/weather_news/model_unet_processed/Test_Predictions/Test_Image_Predictions_' + str(t+2))
      plt.show()

      t = t+2
                    
    return Y_pred

# %%
# Function for a single resolution convolution operations

def conv_layer(input_layer, conv_channels, kernel_size = (3,3), pool_stride = (2,2), dropout_rate = 0.2, padding = 'same', activation = 'relu'):        
    
    layer_1 = tf.keras.layers.Conv2D(conv_channels, kernel_size, activation = activation, padding = padding, kernel_initializer = 'he_normal')(input_layer)
    layer_2 = tf.keras.layers.BatchNormalization()(layer_1)
    layer_3 = tf.keras.layers.Dropout(dropout_rate)(layer_2)
    layer_4 = tf.keras.layers.Conv2D(conv_channels, kernel_size, activation = activation, padding = padding, kernel_initializer = 'he_normal')(layer_3)
    layer_5 = tf.keras.layers.BatchNormalization()(layer_4)
    layer_6 = tf.keras.layers.MaxPool2D(pool_stride)(layer_5)
    
    return layer_1,layer_6

# %%
# Function for a single resolution convolution operation at the terminal position

def terminal_conv_layer(input_layer, conv_channels, kernel_size = (3,3), dropout_rate = 0.2, padding = 'same', activation = 'relu'):
    
    layer_1 = tf.keras.layers.Conv2D(conv_channels, kernel_size, activation = activation, padding = padding, kernel_initializer = 'he_normal')(input_layer)
    layer_2 = tf.keras.layers.BatchNormalization()(layer_1)
    layer_3 = tf.keras.layers.Dropout(dropout_rate)(layer_2)
    layer_4 = tf.keras.layers.Conv2D(conv_channels, kernel_size, activation = activation, padding = padding, kernel_initializer = 'he_normal')(layer_3)
    layer_5 = tf.keras.layers.BatchNormalization()(layer_4)
    
    return layer_5

# %%
# Function for a single resolution transpose convolution operation

def transpose_conv_layer(input_layer, skip_layer, conv_channels, kernel_size = (3,3), transpose_kernel_size = (2,2), dropout_rate = 0.2, padding = 'same', activation = 'relu', transpose_strides = (2,2)):
    
    layer_1 = tf.keras.layers.Conv2DTranspose(conv_channels, transpose_kernel_size, strides = transpose_strides, padding = padding )(input_layer)
    layer_2 = tf.keras.layers.concatenate([layer_1, skip_layer], axis = 3)
    
    layer_3 = tf.keras.layers.Conv2D(conv_channels, kernel_size, activation = activation, padding = padding, kernel_initializer = 'he_normal')(layer_2)
    layer_4 = tf.keras.layers.BatchNormalization()(layer_3)
    layer_5 = tf.keras.layers.Dropout(dropout_rate)(layer_4)
    layer_6 = tf.keras.layers.Conv2D(conv_channels, kernel_size, activation = activation, padding = padding, kernel_initializer = 'he_normal')(layer_5)
    layer_7 = tf.keras.layers.BatchNormalization()(layer_6)    
    
    return layer_7

# %%
# The final U-Net model of this program

def modified_unet_model(height, width, image_channels):
    
    inputs = tf.keras.layers.Input((height, width, image_channels))
    normalized_inputs = tf.keras.layers.Lambda(lambda x: x/255)(inputs)

    S1,D1 = conv_layer(normalized_inputs, 16)
    S2,D2 = conv_layer(D1, 32)
    S3,D3 = conv_layer(D2, 64)
    S4,D4 = conv_layer(D3, 128)
    S5,D5 = conv_layer(D4, 256)

    T1 = terminal_conv_layer(D5, 512)

    U1 = transpose_conv_layer(T1, S5, 256)
    U2 = transpose_conv_layer(U1, S4, 128)
    U3 = transpose_conv_layer(U2, S3, 64)
    U4 = transpose_conv_layer(U3, S2, 32)
    U5 = transpose_conv_layer(U4, S1, 16)

    outputs = tf.keras.layers.Conv2D(4,(1,1), activation = 'sigmoid')(U5)

    model = Model(inputs = [inputs], outputs = [outputs])
    
    model.summary()
    
    return model

# %%
# This function creates an instance of the model and compiles it with the entered optimizers, loss criterion and metrics and prints the summary of the model

def model_construction(X,Y,optimizer,loss,metrics):
    
    h = X.shape[1]
    w = X.shape[2]
    c = X.shape[3]
    
    unet_model = modified_unet_model(h,w,c)
    
    unet_model.compile(optimizer = optimizer, loss = loss, metrics = [metrics])
    unet_model.summary()
    
    return unet_model

# %%
# Calculation of intersection over union of predicted segmentations

def IoU(Y_pred , Y, smooth = 1):
    
    I_Area = tf.keras.backend.sum(tf.keras.backend.abs(np.multiply(Y_pred,Y)), axis = [1,2,3])
    U_Area = tf.keras.backend.sum(Y_pred, axis = [1,2,3]) + tf.keras.backend.sum(Y, axis = [1,2,3]) - I_Area
    IoU_value = I_Area/U_Area
    
    m = Y.shape[0]
    for i in range(m):   
        print("IoU of Image " + str(i+1) + " = " + str(IoU_value[i]))
        
    mean_IoU = tf.keras.backend.mean((I_Area + smooth)/(U_Area + smooth), axis = 0) 
    
    return mean_IoU

# %%
# processing the training image labels before training
Y = label_preprocess(Y_init,m,height,width,4,color_list)

# %%
# loading the earlier trained model

trained_model = model_construction(X,Y,'sgd','binary_crossentropy','acc')
checkpoint_filepath = '/content/drive/My Drive/weather_news/model_unet_processed/checkpoint'
checkpoint_directory = os.path.dirname(checkpoint_filepath)
latest = tf.train.latest_checkpoint(checkpoint_directory)
trained_model.load_weights(latest)
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 160, 160, 3) 0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 160, 160, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 160, 160, 16) 448         lambda[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 160, 160, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 160, 160, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 160, 160, 16) 2320        dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 160, 160, 16) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 80, 80, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 80, 80, 32)   4640        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 80, 80, 32)   128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 80, 80, 32)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 80, 80, 32)   9248        dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 80, 80, 32)   128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 40, 40, 32)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 40, 40, 64)   18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 40, 40, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 40, 40, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 40, 40, 64)   36928       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 40, 40, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 20, 20, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 20, 20, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 20, 20, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 20, 20, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 20, 20, 128)  147584      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 20, 20, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 10, 10, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 10, 10, 256)  295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 10, 10, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 10, 10, 256)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 10, 10, 256)  590080      dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 10, 10, 256)  1024        conv2d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 5, 5, 256)    0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 5, 5, 512)    1180160     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 5, 5, 512)    2048        conv2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 5, 5, 512)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 5, 5, 512)    2359808     dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 5, 5, 512)    2048        conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 10, 10, 256)  524544      batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 10, 10, 512)  0           conv2d_transpose[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 10, 10, 256)  1179904     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 10, 10, 256)  1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 10, 10, 256)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 10, 10, 256)  590080      dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 10, 10, 256)  1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 20, 20, 128)  131200      batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 20, 20, 256)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 20, 20, 128)  295040      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 20, 20, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 20, 20, 128)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 20, 20, 128)  147584      dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 20, 20, 128)  512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 40, 40, 64)   32832       batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 40, 40, 128)  0           conv2d_transpose_2[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 40, 40, 64)   73792       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 40, 40, 64)   256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 40, 40, 64)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 40, 40, 64)   36928       dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 40, 40, 64)   256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 80, 80, 32)   8224        batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 80, 80, 64)   0           conv2d_transpose_3[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 80, 80, 32)   18464       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 80, 80, 32)   128         conv2d_18[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 80, 80, 32)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 80, 80, 32)   9248        dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 80, 80, 32)   128         conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 160, 160, 16) 2064        batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 160, 160, 32) 0           conv2d_transpose_4[0][0]
#                                                                  conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 160, 160, 16) 4624        concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 160, 160, 16) 64          conv2d_20[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 160, 160, 16) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 160, 160, 16) 2320        dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 160, 160, 16) 64          conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 160, 160, 4)  68          batch_normalization_21[0][0]
# ==================================================================================================
# Total params: 7,787,684
# Trainable params: 7,781,668
# Non-trainable params: 6,016
# __________________________________________________________________________________________________
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 160, 160, 3) 0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 160, 160, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 160, 160, 16) 448         lambda[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 160, 160, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 160, 160, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 160, 160, 16) 2320        dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 160, 160, 16) 64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 80, 80, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 80, 80, 32)   4640        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 80, 80, 32)   128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 80, 80, 32)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 80, 80, 32)   9248        dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 80, 80, 32)   128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 40, 40, 32)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 40, 40, 64)   18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 40, 40, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 40, 40, 64)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 40, 40, 64)   36928       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 40, 40, 64)   256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 20, 20, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 20, 20, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 20, 20, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 20, 20, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 20, 20, 128)  147584      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 20, 20, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 10, 10, 128)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 10, 10, 256)  295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 10, 10, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 10, 10, 256)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 10, 10, 256)  590080      dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 10, 10, 256)  1024        conv2d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 5, 5, 256)    0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 5, 5, 512)    1180160     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 5, 5, 512)    2048        conv2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 5, 5, 512)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 5, 5, 512)    2359808     dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 5, 5, 512)    2048        conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 10, 10, 256)  524544      batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 10, 10, 512)  0           conv2d_transpose[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 10, 10, 256)  1179904     concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 10, 10, 256)  1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 10, 10, 256)  0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 10, 10, 256)  590080      dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 10, 10, 256)  1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 20, 20, 128)  131200      batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 20, 20, 256)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 20, 20, 128)  295040      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 20, 20, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 20, 20, 128)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 20, 20, 128)  147584      dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 20, 20, 128)  512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 40, 40, 64)   32832       batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 40, 40, 128)  0           conv2d_transpose_2[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 40, 40, 64)   73792       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 40, 40, 64)   256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 40, 40, 64)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 40, 40, 64)   36928       dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 40, 40, 64)   256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 80, 80, 32)   8224        batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 80, 80, 64)   0           conv2d_transpose_3[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 80, 80, 32)   18464       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 80, 80, 32)   128         conv2d_18[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 80, 80, 32)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 80, 80, 32)   9248        dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 80, 80, 32)   128         conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 160, 160, 16) 2064        batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 160, 160, 32) 0           conv2d_transpose_4[0][0]
#                                                                  conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 160, 160, 16) 4624        concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 160, 160, 16) 64          conv2d_20[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 160, 160, 16) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 160, 160, 16) 2320        dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 160, 160, 16) 64          conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 160, 160, 4)  68          batch_normalization_21[0][0]
# ==================================================================================================
# Total params: 7,787,684
# Trainable params: 7,781,668
# Non-trainable params: 6,016
# __________________________________________________________________________________________________

# %%
# predictions over test images

testing_directory = r'/content/drive/My Drive/weather_news/test_images'
prediction_postprocess(trained_model,testing_directory,len(os.listdir(testing_directory)),160,160,4,color_list)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Predictions for calculating the mean IoU

Y_pred_init = trained_model.predict(X)
Y_prediction = np.zeros([X.shape[0],height,width,4]) 

for n in range(X.shape[0]):
  for i in range(height):
    for j in range(width):

      ch = np.argmax(Y_pred_init[n,i,j,:])

      if ch == 0:
        Y_prediction[n,i,j,:] = np.array((1,0,0,0))
      elif ch == 1:
        Y_prediction[n,i,j,:] = np.array((0,1,0,0))
      elif ch == 2:
        Y_prediction[n,i,j,:] = np.array((0,0,1,0))
      elif ch == 3:
        Y_prediction[n,i,j,:] = np.array((0,0,0,1))

# %%
# mean IoU calculations

mean_iou = IoU(Y_prediction,Y)
print("\n\n Mean intersection over Union is " + str(mean_iou*100) )
# Out:
# IoU of Image 1 = tf.Tensor(0.860127157129882, shape=(), dtype=float64)
# IoU of Image 2 = tf.Tensor(0.6139200605220023, shape=(), dtype=float64)
# IoU of Image 3 = tf.Tensor(0.7939144392490753, shape=(), dtype=float64)
# IoU of Image 4 = tf.Tensor(0.8156672222419235, shape=(), dtype=float64)
# IoU of Image 5 = tf.Tensor(0.7817371937639198, shape=(), dtype=float64)
# IoU of Image 6 = tf.Tensor(0.4245737016328688, shape=(), dtype=float64)
# IoU of Image 7 = tf.Tensor(0.9013542514615556, shape=(), dtype=float64)
# IoU of Image 8 = tf.Tensor(0.6805619378979847, shape=(), dtype=float64)
# IoU of Image 9 = tf.Tensor(0.48634133596539614, shape=(), dtype=float64)
# IoU of Image 10 = tf.Tensor(0.8137376456835169, shape=(), dtype=float64)
# IoU of Image 11 = tf.Tensor(0.8951030832438834, shape=(), dtype=float64)
# IoU of Image 12 = tf.Tensor(0.8637692668664043, shape=(), dtype=float64)
# IoU of Image 13 = tf.Tensor(0.9460281261877613, shape=(), dtype=float64)
# IoU of Image 14 = tf.Tensor(0.8817614678899083, shape=(), dtype=float64)
# IoU of Image 15 = tf.Tensor(0.7633890132598588, shape=(), dtype=float64)
# IoU of Image 16 = tf.Tensor(0.8072714436992587, shape=(), dtype=float64)
# IoU of Image 17 = tf.Tensor(0.7120117220020646, shape=(), dtype=float64)
# IoU of Image 18 = tf.Tensor(0.8716870773167611, shape=(), dtype=float64)
# IoU of Image 19 = tf.Tensor(0.807143865593675, shape=(), dtype=float64)
# IoU of Image 20 = tf.Tensor(0.7581813811338897, shape=(), dtype=float64)
# IoU of Image 21 = tf.Tensor(0.603278176709335, shape=(), dtype=float64)
# IoU of Image 22 = tf.Tensor(0.6981194653576995, shape=(), dtype=float64)
# IoU of Image 23 = tf.Tensor(0.8093995698621443, shape=(), dtype=float64)
# IoU of Image 24 = tf.Tensor(0.8309254756115005, shape=(), dtype=float64)
# IoU of Image 25 = tf.Tensor(0.2632422964004638, shape=(), dtype=float64)
# IoU of Image 26 = tf.Tensor(0.40447126594431493, shape=(), dtype=float64)
# IoU of Image 27 = tf.Tensor(0.9516657772356484, shape=(), dtype=float64)
# IoU of Image 28 = tf.Tensor(0.8584074006892799, shape=(), dtype=float64)
# IoU of Image 29 = tf.Tensor(0.6506544587013992, shape=(), dtype=float64)
# IoU of Image 30 = tf.Tensor(0.5497714960200962, shape=(), dtype=float64)
# IoU of Image 31 = tf.Tensor(0.8624954528919607, shape=(), dtype=float64)
# IoU of Image 32 = tf.Tensor(0.7902911268978966, shape=(), dtype=float64)
# IoU of Image 33 = tf.Tensor(0.8712766346259274, shape=(), dtype=float64)
# IoU of Image 34 = tf.Tensor(0.9379991672659829, shape=(), dtype=float64)
# IoU of Image 35 = tf.Tensor(0.9344113646667674, shape=(), dtype=float64)
# IoU of Image 36 = tf.Tensor(0.913045097382043, shape=(), dtype=float64)
# IoU of Image 37 = tf.Tensor(0.7226876619225463, shape=(), dtype=float64)
# IoU of Image 38 = tf.Tensor(0.960408929050044, shape=(), dtype=float64)
# IoU of Image 39 = tf.Tensor(0.8599920078468413, shape=(), dtype=float64)
# IoU of Image 40 = tf.Tensor(0.7780278999965893, shape=(), dtype=float64)
# IoU of Image 41 = tf.Tensor(0.94876869790279, shape=(), dtype=float64)
# IoU of Image 42 = tf.Tensor(0.9540493092130372, shape=(), dtype=float64)
# IoU of Image 43 = tf.Tensor(0.7928296607205316, shape=(), dtype=float64)
# IoU of Image 44 = tf.Tensor(0.9617609870109965, shape=(), dtype=float64)
# IoU of Image 45 = tf.Tensor(0.9495107185013136, shape=(), dtype=float64)
# IoU of Image 46 = tf.Tensor(0.9576588271227856, shape=(), dtype=float64)
# IoU of Image 47 = tf.Tensor(0.6904384574749075, shape=(), dtype=float64)
# IoU of Image 48 = tf.Tensor(0.8489094323270259, shape=(), dtype=float64)
# IoU of Image 49 = tf.Tensor(0.6877080792431685, shape=(), dtype=float64)
# IoU of Image 50 = tf.Tensor(0.9045493434512517, shape=(), dtype=float64)
# IoU of Image 51 = tf.Tensor(0.3835594227963033, shape=(), dtype=float64)
# IoU of Image 52 = tf.Tensor(0.9302448210922787, shape=(), dtype=float64)
# IoU of Image 53 = tf.Tensor(0.9687007344176568, shape=(), dtype=float64)
# IoU of Image 54 = tf.Tensor(0.9085961380750018, shape=(), dtype=float64)
# IoU of Image 55 = tf.Tensor(0.86324102041559, shape=(), dtype=float64)
# IoU of Image 56 = tf.Tensor(0.8210271731398492, shape=(), dtype=float64)
# IoU of Image 57 = tf.Tensor(0.9550192829050365, shape=(), dtype=float64)
# IoU of Image 58 = tf.Tensor(0.8335482022632861, shape=(), dtype=float64)
# IoU of Image 59 = tf.Tensor(0.9668856363566517, shape=(), dtype=float64)
# IoU of Image 60 = tf.Tensor(0.7584833081467235, shape=(), dtype=float64)
# IoU of Image 61 = tf.Tensor(0.8475083895644643, shape=(), dtype=float64)
# IoU of Image 62 = tf.Tensor(0.6571622758754612, shape=(), dtype=float64)
# IoU of Image 63 = tf.Tensor(0.9795855242808537, shape=(), dtype=float64)
# IoU of Image 64 = tf.Tensor(0.9289454846852278, shape=(), dtype=float64)
# IoU of Image 65 = tf.Tensor(0.9257531876480987, shape=(), dtype=float64)
# IoU of Image 66 = tf.Tensor(0.9203765517758692, shape=(), dtype=float64)
# IoU of Image 67 = tf.Tensor(0.6823698760100763, shape=(), dtype=float64)
# IoU of Image 68 = tf.Tensor(0.9613852283174993, shape=(), dtype=float64)
# IoU of Image 69 = tf.Tensor(0.3867255199306759, shape=(), dtype=float64)
# IoU of Image 70 = tf.Tensor(0.721413441818243, shape=(), dtype=float64)
# IoU of Image 71 = tf.Tensor(0.9144481005085253, shape=(), dtype=float64)
# IoU of Image 72 = tf.Tensor(0.5231748676146843, shape=(), dtype=float64)
# IoU of Image 73 = tf.Tensor(0.9241609981585178, shape=(), dtype=float64)
# IoU of Image 74 = tf.Tensor(0.946694042051633, shape=(), dtype=float64)
# IoU of Image 75 = tf.Tensor(0.7081484940462293, shape=(), dtype=float64)
# IoU of Image 76 = tf.Tensor(0.826912100456621, shape=(), dtype=float64)
# IoU of Image 77 = tf.Tensor(0.9256083342735718, shape=(), dtype=float64)
# IoU of Image 78 = tf.Tensor(0.9697610895241027, shape=(), dtype=float64)
# IoU of Image 79 = tf.Tensor(0.958009866534093, shape=(), dtype=float64)
# IoU of Image 80 = tf.Tensor(0.8880851845052322, shape=(), dtype=float64)
# IoU of Image 81 = tf.Tensor(0.6995286463519883, shape=(), dtype=float64)
# IoU of Image 82 = tf.Tensor(0.14778577637121398, shape=(), dtype=float64)
# IoU of Image 83 = tf.Tensor(0.9338999055712937, shape=(), dtype=float64)
# IoU of Image 84 = tf.Tensor(0.8032654777337865, shape=(), dtype=float64)
# IoU of Image 85 = tf.Tensor(0.8784854710889346, shape=(), dtype=float64)
# IoU of Image 86 = tf.Tensor(0.6760922092339842, shape=(), dtype=float64)
# IoU of Image 87 = tf.Tensor(0.5355065075271397, shape=(), dtype=float64)
# IoU of Image 88 = tf.Tensor(0.8088396229745473, shape=(), dtype=float64)
# IoU of Image 89 = tf.Tensor(0.8107869142351901, shape=(), dtype=float64)
# IoU of Image 90 = tf.Tensor(0.6648048321101513, shape=(), dtype=float64)
# IoU of Image 91 = tf.Tensor(0.9330967303481085, shape=(), dtype=float64)
# IoU of Image 92 = tf.Tensor(0.9092665527234897, shape=(), dtype=float64)
# IoU of Image 93 = tf.Tensor(0.9382192610539067, shape=(), dtype=float64)
# IoU of Image 94 = tf.Tensor(0.6367808089119564, shape=(), dtype=float64)
# IoU of Image 95 = tf.Tensor(0.7923828193369973, shape=(), dtype=float64)
# IoU of Image 96 = tf.Tensor(0.6788536577368266, shape=(), dtype=float64)
# IoU of Image 97 = tf.Tensor(0.9702158771693539, shape=(), dtype=float64)
# IoU of Image 98 = tf.Tensor(0.9025677232358515, shape=(), dtype=float64)
# IoU of Image 99 = tf.Tensor(0.8973503798406522, shape=(), dtype=float64)
# IoU of Image 100 = tf.Tensor(0.9775211463442895, shape=(), dtype=float64)
# IoU of Image 101 = tf.Tensor(0.9053289669544508, shape=(), dtype=float64)
# IoU of Image 102 = tf.Tensor(0.9714296715567363, shape=(), dtype=float64)
# IoU of Image 103 = tf.Tensor(0.8050414242904989, shape=(), dtype=float64)
# IoU of Image 104 = tf.Tensor(0.6689767366194892, shape=(), dtype=float64)
# IoU of Image 105 = tf.Tensor(0.6333822497288331, shape=(), dtype=float64)
# IoU of Image 106 = tf.Tensor(0.7396483844691827, shape=(), dtype=float64)
# IoU of Image 107 = tf.Tensor(0.6561539705644509, shape=(), dtype=float64)
# IoU of Image 108 = tf.Tensor(0.8833915762368953, shape=(), dtype=float64)
# IoU of Image 109 = tf.Tensor(0.5765488360635547, shape=(), dtype=float64)
# IoU of Image 110 = tf.Tensor(0.8017859605571646, shape=(), dtype=float64)
# IoU of Image 111 = tf.Tensor(0.8810389801241779, shape=(), dtype=float64)
# IoU of Image 112 = tf.Tensor(0.9584592433921126, shape=(), dtype=float64)
# IoU of Image 113 = tf.Tensor(0.8073352395072187, shape=(), dtype=float64)
# IoU of Image 114 = tf.Tensor(0.9718092890703227, shape=(), dtype=float64)
# IoU of Image 115 = tf.Tensor(0.6734907108107225, shape=(), dtype=float64)
# IoU of Image 116 = tf.Tensor(0.8811906594816525, shape=(), dtype=float64)
# IoU of Image 117 = tf.Tensor(1.0, shape=(), dtype=float64)
# IoU of Image 118 = tf.Tensor(0.9171003856666792, shape=(), dtype=float64)
# IoU of Image 119 = tf.Tensor(0.9235104064918476, shape=(), dtype=float64)
# IoU of Image 120 = tf.Tensor(0.7466653020843994, shape=(), dtype=float64)
# IoU of Image 121 = tf.Tensor(0.7785077428437354, shape=(), dtype=float64)
# IoU of Image 122 = tf.Tensor(0.8537291817523533, shape=(), dtype=float64)
# IoU of Image 123 = tf.Tensor(0.8685593344037367, shape=(), dtype=float64)
# IoU of Image 124 = tf.Tensor(0.8671820867218555, shape=(), dtype=float64)
# IoU of Image 125 = tf.Tensor(0.9862668270163324, shape=(), dtype=float64)
# IoU of Image 126 = tf.Tensor(0.3743490631878456, shape=(), dtype=float64)
# IoU of Image 127 = tf.Tensor(0.5429712124395881, shape=(), dtype=float64)
# IoU of Image 128 = tf.Tensor(0.7676342825622285, shape=(), dtype=float64)
# IoU of Image 129 = tf.Tensor(0.53758145401039, shape=(), dtype=float64)
# IoU of Image 130 = tf.Tensor(0.7131831941718506, shape=(), dtype=float64)
# IoU of Image 131 = tf.Tensor(0.5425868458317014, shape=(), dtype=float64)
# IoU of Image 132 = tf.Tensor(0.8934211012906328, shape=(), dtype=float64)
# IoU of Image 133 = tf.Tensor(0.7984474340510731, shape=(), dtype=float64)
# IoU of Image 134 = tf.Tensor(0.833810888252149, shape=(), dtype=float64)
# IoU of Image 135 = tf.Tensor(0.6125274036955841, shape=(), dtype=float64)
# IoU of Image 136 = tf.Tensor(0.9304000301625005, shape=(), dtype=float64)
# IoU of Image 137 = tf.Tensor(0.5841584158415841, shape=(), dtype=float64)
# IoU of Image 138 = tf.Tensor(0.585532020314629, shape=(), dtype=float64)
# IoU of Image 139 = tf.Tensor(0.9527186761229315, shape=(), dtype=float64)
# IoU of Image 140 = tf.Tensor(0.8238922367954626, shape=(), dtype=float64)
# IoU of Image 141 = tf.Tensor(0.9244035318429457, shape=(), dtype=float64)
# IoU of Image 142 = tf.Tensor(0.9077427528131754, shape=(), dtype=float64)
# IoU of Image 143 = tf.Tensor(0.8575674108437228, shape=(), dtype=float64)
# IoU of Image 144 = tf.Tensor(0.873502530677639, shape=(), dtype=float64)
# IoU of Image 145 = tf.Tensor(0.7853865406006674, shape=(), dtype=float64)
# IoU of Image 146 = tf.Tensor(0.9476567255021302, shape=(), dtype=float64)
# IoU of Image 147 = tf.Tensor(0.8464423527714667, shape=(), dtype=float64)
# IoU of Image 148 = tf.Tensor(0.8212214989506634, shape=(), dtype=float64)
# IoU of Image 149 = tf.Tensor(0.9435165502581233, shape=(), dtype=float64)
# IoU of Image 150 = tf.Tensor(0.7316602969526838, shape=(), dtype=float64)
# IoU of Image 151 = tf.Tensor(0.9643953345610804, shape=(), dtype=float64)
# IoU of Image 152 = tf.Tensor(0.942263191836425, shape=(), dtype=float64)
# IoU of Image 153 = tf.Tensor(0.2604317963614879, shape=(), dtype=float64)
# IoU of Image 154 = tf.Tensor(0.6186577308506939, shape=(), dtype=float64)
# IoU of Image 155 = tf.Tensor(0.9650738821723278, shape=(), dtype=float64)
# IoU of Image 156 = tf.Tensor(0.9380725263078205, shape=(), dtype=float64)
# IoU of Image 157 = tf.Tensor(0.25, shape=(), dtype=float64)
# IoU of Image 158 = tf.Tensor(0.9808875304677526, shape=(), dtype=float64)
# IoU of Image 159 = tf.Tensor(0.39951891537284057, shape=(), dtype=float64)
# IoU of Image 160 = tf.Tensor(0.810752688172043, shape=(), dtype=float64)
# IoU of Image 161 = tf.Tensor(0.8973503798406522, shape=(), dtype=float64)
# IoU of Image 162 = tf.Tensor(0.39757062917974617, shape=(), dtype=float64)
# IoU of Image 163 = tf.Tensor(0.9369727234895774, shape=(), dtype=float64)
# IoU of Image 164 = tf.Tensor(0.8183755371666016, shape=(), dtype=float64)
# IoU of Image 165 = tf.Tensor(0.7857737393355066, shape=(), dtype=float64)
# IoU of Image 166 = tf.Tensor(0.895243383305571, shape=(), dtype=float64)
# IoU of Image 167 = tf.Tensor(0.7698598937124715, shape=(), dtype=float64)
# IoU of Image 168 = tf.Tensor(0.9530802975395766, shape=(), dtype=float64)
# IoU of Image 169 = tf.Tensor(0.8664116575591986, shape=(), dtype=float64)
# IoU of Image 170 = tf.Tensor(0.8940514945250074, shape=(), dtype=float64)
# IoU of Image 171 = tf.Tensor(0.9612349651421129, shape=(), dtype=float64)
# IoU of Image 172 = tf.Tensor(0.9113035687621323, shape=(), dtype=float64)
# IoU of Image 173 = tf.Tensor(0.30279898218829515, shape=(), dtype=float64)
# IoU of Image 174 = tf.Tensor(0.8797958659176855, shape=(), dtype=float64)
# IoU of Image 175 = tf.Tensor(0.9194001874414246, shape=(), dtype=float64)
# IoU of Image 176 = tf.Tensor(0.9698368728839643, shape=(), dtype=float64)
# IoU of Image 177 = tf.Tensor(0.5424009640006024, shape=(), dtype=float64)
# IoU of Image 178 = tf.Tensor(0.7009401681007276, shape=(), dtype=float64)
# IoU of Image 179 = tf.Tensor(0.5330781193922718, shape=(), dtype=float64)
# IoU of Image 180 = tf.Tensor(0.8285714285714286, shape=(), dtype=float64)
# IoU of Image 181 = tf.Tensor(0.9527078565980168, shape=(), dtype=float64)
# IoU of Image 182 = tf.Tensor(0.6038592864079191, shape=(), dtype=float64)
# IoU of Image 183 = tf.Tensor(0.8986090100726857, shape=(), dtype=float64)
# IoU of Image 184 = tf.Tensor(0.6917231125061952, shape=(), dtype=float64)
# IoU of Image 185 = tf.Tensor(0.8172783417335132, shape=(), dtype=float64)
# IoU of Image 186 = tf.Tensor(0.47938516656554275, shape=(), dtype=float64)
# IoU of Image 187 = tf.Tensor(0.7911492041280391, shape=(), dtype=float64)
# IoU of Image 188 = tf.Tensor(0.9206242028659314, shape=(), dtype=float64)
# IoU of Image 189 = tf.Tensor(0.6544949266464163, shape=(), dtype=float64)
# IoU of Image 190 = tf.Tensor(0.7890569243840272, shape=(), dtype=float64)
# IoU of Image 191 = tf.Tensor(0.8676307007786429, shape=(), dtype=float64)
# IoU of Image 192 = tf.Tensor(0.7744490358126722, shape=(), dtype=float64)
# IoU of Image 193 = tf.Tensor(0.311710603848026, shape=(), dtype=float64)
# IoU of Image 194 = tf.Tensor(0.9012253991830672, shape=(), dtype=float64)
# IoU of Image 195 = tf.Tensor(0.929454326198372, shape=(), dtype=float64)
# IoU of Image 196 = tf.Tensor(0.8688733987810664, shape=(), dtype=float64)
# IoU of Image 197 = tf.Tensor(0.7843451592667456, shape=(), dtype=float64)
# IoU of Image 198 = tf.Tensor(0.6990404187263739, shape=(), dtype=float64)
# IoU of Image 199 = tf.Tensor(0.25, shape=(), dtype=float64)
# IoU of Image 200 = tf.Tensor(0.8265910388127854, shape=(), dtype=float64)
# IoU of Image 201 = tf.Tensor(0.8421904796171698, shape=(), dtype=float64)
# IoU of Image 202 = tf.Tensor(0.9249859207809273, shape=(), dtype=float64)
# IoU of Image 203 = tf.Tensor(0.9145196873948322, shape=(), dtype=float64)
# IoU of Image 204 = tf.Tensor(0.7276508477513648, shape=(), dtype=float64)
# IoU of Image 205 = tf.Tensor(0.9544222620910792, shape=(), dtype=float64)
# IoU of Image 206 = tf.Tensor(0.840657186642432, shape=(), dtype=float64)
# IoU of Image 207 = tf.Tensor(0.8485089176113799, shape=(), dtype=float64)
# IoU of Image 208 = tf.Tensor(0.8351254480286738, shape=(), dtype=float64)
# IoU of Image 209 = tf.Tensor(0.9482496194824962, shape=(), dtype=float64)
# IoU of Image 210 = tf.Tensor(0.49353869490388264, shape=(), dtype=float64)
# IoU of Image 211 = tf.Tensor(0.9470271500075838, shape=(), dtype=float64)
# IoU of Image 212 = tf.Tensor(0.7616058096918692, shape=(), dtype=float64)
# IoU of Image 213 = tf.Tensor(0.9845730454668785, shape=(), dtype=float64)
# IoU of Image 214 = tf.Tensor(0.45839860996382487, shape=(), dtype=float64)
# IoU of Image 215 = tf.Tensor(0.9282190336308515, shape=(), dtype=float64)
# IoU of Image 216 = tf.Tensor(0.9295270397588091, shape=(), dtype=float64)
# IoU of Image 217 = tf.Tensor(0.9640185661130077, shape=(), dtype=float64)
# IoU of Image 218 = tf.Tensor(0.8537061823969901, shape=(), dtype=float64)
# IoU of Image 219 = tf.Tensor(0.8795888399412628, shape=(), dtype=float64)
# IoU of Image 220 = tf.Tensor(0.6529459241323649, shape=(), dtype=float64)
# IoU of Image 221 = tf.Tensor(0.25, shape=(), dtype=float64)
# IoU of Image 222 = tf.Tensor(0.9347037484885127, shape=(), dtype=float64)
# IoU of Image 223 = tf.Tensor(0.9547031684904869, shape=(), dtype=float64)
# IoU of Image 224 = tf.Tensor(0.7170836407539071, shape=(), dtype=float64)
# IoU of Image 225 = tf.Tensor(0.5124863637703806, shape=(), dtype=float64)
# IoU of Image 226 = tf.Tensor(0.8752518038310808, shape=(), dtype=float64)
# IoU of Image 227 = tf.Tensor(0.8702513150204558, shape=(), dtype=float64)
# IoU of Image 228 = tf.Tensor(0.8760475754803294, shape=(), dtype=float64)
# IoU of Image 229 = tf.Tensor(0.9167415393830488, shape=(), dtype=float64)
# IoU of Image 230 = tf.Tensor(0.9536019536019537, shape=(), dtype=float64)
# IoU of Image 231 = tf.Tensor(0.7012130452074772, shape=(), dtype=float64)
# IoU of Image 232 = tf.Tensor(0.6390694710006374, shape=(), dtype=float64)
# IoU of Image 233 = tf.Tensor(0.847175120860091, shape=(), dtype=float64)
# IoU of Image 234 = tf.Tensor(0.8523208277558699, shape=(), dtype=float64)
# IoU of Image 235 = tf.Tensor(0.5057937768366567, shape=(), dtype=float64)
# IoU of Image 236 = tf.Tensor(0.9504018894518305, shape=(), dtype=float64)
# IoU of Image 237 = tf.Tensor(0.6147781386987922, shape=(), dtype=float64)
# IoU of Image 238 = tf.Tensor(0.9068901303538175, shape=(), dtype=float64)
# IoU of Image 239 = tf.Tensor(0.9363866722136076, shape=(), dtype=float64)
# IoU of Image 240 = tf.Tensor(0.9336077646436799, shape=(), dtype=float64)
# IoU of Image 241 = tf.Tensor(0.9447715273293577, shape=(), dtype=float64)
# IoU of Image 242 = tf.Tensor(0.25604101758948067, shape=(), dtype=float64)
# IoU of Image 243 = tf.Tensor(0.6295871924631592, shape=(), dtype=float64)
# IoU of Image 244 = tf.Tensor(0.4491112872183856, shape=(), dtype=float64)
# IoU of Image 245 = tf.Tensor(0.8872792952191382, shape=(), dtype=float64)
# IoU of Image 246 = tf.Tensor(0.9571732846493229, shape=(), dtype=float64)
# IoU of Image 247 = tf.Tensor(0.9309096394629658, shape=(), dtype=float64)
# IoU of Image 248 = tf.Tensor(0.25, shape=(), dtype=float64)
# IoU of Image 249 = tf.Tensor(0.5154178503787878, shape=(), dtype=float64)
# IoU of Image 250 = tf.Tensor(0.7354755609789166, shape=(), dtype=float64)
# IoU of Image 251 = tf.Tensor(0.7957351290684624, shape=(), dtype=float64)
# IoU of Image 252 = tf.Tensor(0.6034235916588858, shape=(), dtype=float64)
# IoU of Image 253 = tf.Tensor(0.9309710596449082, shape=(), dtype=float64)
# IoU of Image 254 = tf.Tensor(0.8507716216704615, shape=(), dtype=float64)
# IoU of Image 255 = tf.Tensor(0.7421484228793086, shape=(), dtype=float64)
# IoU of Image 256 = tf.Tensor(0.6897891963109355, shape=(), dtype=float64)
# IoU of Image 257 = tf.Tensor(0.9043368295767313, shape=(), dtype=float64)
# IoU of Image 258 = tf.Tensor(0.9400553218900383, shape=(), dtype=float64)
# IoU of Image 259 = tf.Tensor(0.9756897549681651, shape=(), dtype=float64)
# IoU of Image 260 = tf.Tensor(0.9535536751034038, shape=(), dtype=float64)
# IoU of Image 261 = tf.Tensor(0.879450847955363, shape=(), dtype=float64)
# IoU of Image 262 = tf.Tensor(0.7184668053970598, shape=(), dtype=float64)
# IoU of Image 263 = tf.Tensor(0.24037017297349678, shape=(), dtype=float64)
# IoU of Image 264 = tf.Tensor(0.10140439168118373, shape=(), dtype=float64)
# IoU of Image 265 = tf.Tensor(0.7378317833140995, shape=(), dtype=float64)
# IoU of Image 266 = tf.Tensor(0.8780031544584235, shape=(), dtype=float64)
# IoU of Image 267 = tf.Tensor(0.46521189120809614, shape=(), dtype=float64)
# IoU of Image 268 = tf.Tensor(0.965828373968132, shape=(), dtype=float64)
# IoU of Image 269 = tf.Tensor(0.7265216658236385, shape=(), dtype=float64)
# IoU of Image 270 = tf.Tensor(0.8232319635353608, shape=(), dtype=float64)
# IoU of Image 271 = tf.Tensor(0.8950329410022948, shape=(), dtype=float64)
# IoU of Image 272 = tf.Tensor(0.4469225401256106, shape=(), dtype=float64)
# IoU of Image 273 = tf.Tensor(0.9713537655937163, shape=(), dtype=float64)
# IoU of Image 274 = tf.Tensor(0.8606679507213723, shape=(), dtype=float64)
# IoU of Image 275 = tf.Tensor(0.8350323711413957, shape=(), dtype=float64)
# IoU of Image 276 = tf.Tensor(0.7929109684621826, shape=(), dtype=float64)
# IoU of Image 277 = tf.Tensor(0.8895080636232793, shape=(), dtype=float64)
# IoU of Image 278 = tf.Tensor(0.5685583902483844, shape=(), dtype=float64)
# IoU of Image 279 = tf.Tensor(0.9580847483555147, shape=(), dtype=float64)
# IoU of Image 280 = tf.Tensor(0.7910238919788715, shape=(), dtype=float64)
# IoU of Image 281 = tf.Tensor(0.8654133420774583, shape=(), dtype=float64)
# IoU of Image 282 = tf.Tensor(0.9655265077354217, shape=(), dtype=float64)
# IoU of Image 283 = tf.Tensor(0.7628425836661616, shape=(), dtype=float64)
# IoU of Image 284 = tf.Tensor(0.7827064029871387, shape=(), dtype=float64)
# IoU of Image 285 = tf.Tensor(0.9756135206050316, shape=(), dtype=float64)
# IoU of Image 286 = tf.Tensor(0.9433690123737949, shape=(), dtype=float64)
# IoU of Image 287 = tf.Tensor(0.6114310892896484, shape=(), dtype=float64)
# IoU of Image 288 = tf.Tensor(0.8875441436138906, shape=(), dtype=float64)
# IoU of Image 289 = tf.Tensor(0.965161339830411, shape=(), dtype=float64)
# IoU of Image 290 = tf.Tensor(0.9649230533062133, shape=(), dtype=float64)
# IoU of Image 291 = tf.Tensor(0.615484033666425, shape=(), dtype=float64)
# IoU of Image 292 = tf.Tensor(0.7322461684203404, shape=(), dtype=float64)
# IoU of Image 293 = tf.Tensor(0.92004800120003, shape=(), dtype=float64)
# IoU of Image 294 = tf.Tensor(0.7692519535956487, shape=(), dtype=float64)
# IoU of Image 295 = tf.Tensor(0.9021232522009321, shape=(), dtype=float64)
# IoU of Image 296 = tf.Tensor(0.6602354161937806, shape=(), dtype=float64)
# IoU of Image 297 = tf.Tensor(0.7845939351690484, shape=(), dtype=float64)
# IoU of Image 298 = tf.Tensor(0.8751144479033144, shape=(), dtype=float64)
# IoU of Image 299 = tf.Tensor(0.7804979830296286, shape=(), dtype=float64)
# IoU of Image 300 = tf.Tensor(0.6872075397086931, shape=(), dtype=float64)
# IoU of Image 301 = tf.Tensor(0.9209124334058678, shape=(), dtype=float64)
# IoU of Image 302 = tf.Tensor(0.9466200288951411, shape=(), dtype=float64)
# IoU of Image 303 = tf.Tensor(0.9358741681790683, shape=(), dtype=float64)
# IoU of Image 304 = tf.Tensor(0.6490064092241296, shape=(), dtype=float64)
# IoU of Image 305 = tf.Tensor(0.6506827257503542, shape=(), dtype=float64)
# IoU of Image 306 = tf.Tensor(0.9731584800030676, shape=(), dtype=float64)
# IoU of Image 307 = tf.Tensor(0.9007313360804841, shape=(), dtype=float64)
# IoU of Image 308 = tf.Tensor(0.69508359543122, shape=(), dtype=float64)
# IoU of Image 309 = tf.Tensor(0.9011548030151127, shape=(), dtype=float64)
# IoU of Image 310 = tf.Tensor(0.68310322156476, shape=(), dtype=float64)
# IoU of Image 311 = tf.Tensor(0.8214806645558362, shape=(), dtype=float64)
# IoU of Image 312 = tf.Tensor(0.9142333719669495, shape=(), dtype=float64)
# IoU of Image 313 = tf.Tensor(0.7417838788206654, shape=(), dtype=float64)
# IoU of Image 314 = tf.Tensor(0.9608594079123741, shape=(), dtype=float64)
# IoU of Image 315 = tf.Tensor(0.8791060556345474, shape=(), dtype=float64)
# IoU of Image 316 = tf.Tensor(0.7530674322430705, shape=(), dtype=float64)
# IoU of Image 317 = tf.Tensor(0.9287274919008514, shape=(), dtype=float64)
# IoU of Image 318 = tf.Tensor(0.5316523765422878, shape=(), dtype=float64)
# IoU of Image 319 = tf.Tensor(0.7060037960773867, shape=(), dtype=float64)
# IoU of Image 320 = tf.Tensor(0.7131658827846159, shape=(), dtype=float64)
# IoU of Image 321 = tf.Tensor(0.6243654822335025, shape=(), dtype=float64)
# IoU of Image 322 = tf.Tensor(0.9622239957435488, shape=(), dtype=float64)
# IoU of Image 323 = tf.Tensor(0.8207681365576103, shape=(), dtype=float64)
# IoU of Image 324 = tf.Tensor(0.9287274919008514, shape=(), dtype=float64)
# IoU of Image 325 = tf.Tensor(0.3507809202195019, shape=(), dtype=float64)
# IoU of Image 326 = tf.Tensor(0.6199379903821818, shape=(), dtype=float64)
# IoU of Image 327 = tf.Tensor(0.853393665158371, shape=(), dtype=float64)
# IoU of Image 328 = tf.Tensor(0.6833360696109013, shape=(), dtype=float64)
# IoU of Image 329 = tf.Tensor(0.5485588119650364, shape=(), dtype=float64)
# IoU of Image 330 = tf.Tensor(0.8431605471562275, shape=(), dtype=float64)
# IoU of Image 331 = tf.Tensor(0.7791545427796123, shape=(), dtype=float64)
# IoU of Image 332 = tf.Tensor(0.969788984125764, shape=(), dtype=float64)
# IoU of Image 333 = tf.Tensor(0.9525589199908474, shape=(), dtype=float64)
# IoU of Image 334 = tf.Tensor(0.687886971413516, shape=(), dtype=float64)
# IoU of Image 335 = tf.Tensor(0.6683421734303688, shape=(), dtype=float64)
# IoU of Image 336 = tf.Tensor(0.9527078565980168, shape=(), dtype=float64)
# IoU of Image 337 = tf.Tensor(0.6597510373443983, shape=(), dtype=float64)
# IoU of Image 338 = tf.Tensor(0.9352887813728454, shape=(), dtype=float64)
# IoU of Image 339 = tf.Tensor(0.8904848059668427, shape=(), dtype=float64)
# IoU of Image 340 = tf.Tensor(0.8772457285326685, shape=(), dtype=float64)
# IoU of Image 341 = tf.Tensor(0.8451554916412007, shape=(), dtype=float64)
# IoU of Image 342 = tf.Tensor(0.9505504971617966, shape=(), dtype=float64)
# IoU of Image 343 = tf.Tensor(0.28905716303680806, shape=(), dtype=float64)
# IoU of Image 344 = tf.Tensor(0.810422853910338, shape=(), dtype=float64)
# IoU of Image 345 = tf.Tensor(0.7696056406179794, shape=(), dtype=float64)
# IoU of Image 346 = tf.Tensor(0.9396878314896197, shape=(), dtype=float64)
# IoU of Image 347 = tf.Tensor(0.25837227414330216, shape=(), dtype=float64)
# IoU of Image 348 = tf.Tensor(0.6694926307551845, shape=(), dtype=float64)
# IoU of Image 349 = tf.Tensor(0.6668837088162521, shape=(), dtype=float64)
# IoU of Image 350 = tf.Tensor(0.4991045931949083, shape=(), dtype=float64)
# IoU of Image 351 = tf.Tensor(0.9366063998789621, shape=(), dtype=float64)
# IoU of Image 352 = tf.Tensor(0.6181025219644776, shape=(), dtype=float64)
# IoU of Image 353 = tf.Tensor(0.4444914656510086, shape=(), dtype=float64)
# IoU of Image 354 = tf.Tensor(0.9591336955689906, shape=(), dtype=float64)
# IoU of Image 355 = tf.Tensor(0.9607843137254902, shape=(), dtype=float64)
# IoU of Image 356 = tf.Tensor(0.7753120665742025, shape=(), dtype=float64)
# IoU of Image 357 = tf.Tensor(0.9181777311554024, shape=(), dtype=float64)
# IoU of Image 358 = tf.Tensor(0.9682466459078153, shape=(), dtype=float64)
# IoU of Image 359 = tf.Tensor(0.9808108944599195, shape=(), dtype=float64)
# IoU of Image 360 = tf.Tensor(0.90831159150205, shape=(), dtype=float64)
# IoU of Image 361 = tf.Tensor(0.9090637932962977, shape=(), dtype=float64)
# IoU of Image 362 = tf.Tensor(0.7887087758524315, shape=(), dtype=float64)
# IoU of Image 363 = tf.Tensor(0.6880975931421035, shape=(), dtype=float64)
# IoU of Image 364 = tf.Tensor(0.7883339154732798, shape=(), dtype=float64)
# IoU of Image 365 = tf.Tensor(0.9212007504690432, shape=(), dtype=float64)
# IoU of Image 366 = tf.Tensor(0.7371116652065504, shape=(), dtype=float64)
# IoU of Image 367 = tf.Tensor(0.6662327518875293, shape=(), dtype=float64)
# IoU of Image 368 = tf.Tensor(0.5430045702491523, shape=(), dtype=float64)
# IoU of Image 369 = tf.Tensor(0.9762998417416142, shape=(), dtype=float64)
# IoU of Image 370 = tf.Tensor(0.25, shape=(), dtype=float64)
# IoU of Image 371 = tf.Tensor(0.8321227950910587, shape=(), dtype=float64)
# IoU of Image 372 = tf.Tensor(0.47635524798154555, shape=(), dtype=float64)
# IoU of Image 373 = tf.Tensor(0.9013855532976168, shape=(), dtype=float64)
# IoU of Image 374 = tf.Tensor(0.8150235740366549, shape=(), dtype=float64)
# IoU of Image 375 = tf.Tensor(0.8016104645029712, shape=(), dtype=float64)
# IoU of Image 376 = tf.Tensor(0.8473750676528955, shape=(), dtype=float64)
# IoU of Image 377 = tf.Tensor(0.4055508276827628, shape=(), dtype=float64)
# IoU of Image 378 = tf.Tensor(0.901437219148067, shape=(), dtype=float64)
# IoU of Image 379 = tf.Tensor(0.9583094281889463, shape=(), dtype=float64)
# IoU of Image 380 = tf.Tensor(0.8974206937444411, shape=(), dtype=float64)
# IoU of Image 381 = tf.Tensor(0.8104667609618105, shape=(), dtype=float64)
# IoU of Image 382 = tf.Tensor(0.8475750577367206, shape=(), dtype=float64)
# IoU of Image 383 = tf.Tensor(0.913804059357829, shape=(), dtype=float64)
# IoU of Image 384 = tf.Tensor(0.42088313337718003, shape=(), dtype=float64)
# IoU of Image 385 = tf.Tensor(0.6716184008619283, shape=(), dtype=float64)
# IoU of Image 386 = tf.Tensor(0.7585437059934742, shape=(), dtype=float64)
# IoU of Image 387 = tf.Tensor(0.6938302250383773, shape=(), dtype=float64)
# IoU of Image 388 = tf.Tensor(0.8481752878749594, shape=(), dtype=float64)
# IoU of Image 389 = tf.Tensor(0.9879635022325762, shape=(), dtype=float64)
# IoU of Image 390 = tf.Tensor(0.931314121907061, shape=(), dtype=float64)
# IoU of Image 391 = tf.Tensor(0.9439592983521907, shape=(), dtype=float64)
# IoU of Image 392 = tf.Tensor(0.7094096863437885, shape=(), dtype=float64)
# IoU of Image 393 = tf.Tensor(0.7151854209239221, shape=(), dtype=float64)
# IoU of Image 394 = tf.Tensor(0.7489412568306011, shape=(), dtype=float64)
# IoU of Image 395 = tf.Tensor(0.530015688445921, shape=(), dtype=float64)
# IoU of Image 396 = tf.Tensor(0.9735574143314188, shape=(), dtype=float64)
# IoU of Image 397 = tf.Tensor(0.25, shape=(), dtype=float64)
# IoU of Image 398 = tf.Tensor(0.9589088265677009, shape=(), dtype=float64)
# IoU of Image 399 = tf.Tensor(0.7970004645298294, shape=(), dtype=float64)
# IoU of Image 400 = tf.Tensor(0.755432364918044, shape=(), dtype=float64)
# IoU of Image 401 = tf.Tensor(0.9746230089860773, shape=(), dtype=float64)
# IoU of Image 402 = tf.Tensor(0.6229752432877929, shape=(), dtype=float64)
# IoU of Image 403 = tf.Tensor(0.7103724736930015, shape=(), dtype=float64)
# IoU of Image 404 = tf.Tensor(0.7301388841955868, shape=(), dtype=float64)
# IoU of Image 405 = tf.Tensor(0.755281629857901, shape=(), dtype=float64)
# IoU of Image 406 = tf.Tensor(0.8540648198442875, shape=(), dtype=float64)
# IoU of Image 407 = tf.Tensor(0.8966475273198741, shape=(), dtype=float64)
# IoU of Image 408 = tf.Tensor(0.7039454069632624, shape=(), dtype=float64)
# IoU of Image 409 = tf.Tensor(0.950922115531169, shape=(), dtype=float64)
# IoU of Image 410 = tf.Tensor(0.927493129541091, shape=(), dtype=float64)
# IoU of Image 411 = tf.Tensor(0.8660252204971208, shape=(), dtype=float64)
# IoU of Image 412 = tf.Tensor(0.4105460355942476, shape=(), dtype=float64)
# IoU of Image 413 = tf.Tensor(0.7741432482067986, shape=(), dtype=float64)
# IoU of Image 414 = tf.Tensor(0.9309005918498134, shape=(), dtype=float64)
# IoU of Image 415 = tf.Tensor(0.9641692561476196, shape=(), dtype=float64)
# IoU of Image 416 = tf.Tensor(0.8557448350851757, shape=(), dtype=float64)
# IoU of Image 417 = tf.Tensor(0.91990400479976, shape=(), dtype=float64)
# IoU of Image 418 = tf.Tensor(0.8465250270075622, shape=(), dtype=float64)
# IoU of Image 419 = tf.Tensor(0.365471270497267, shape=(), dtype=float64)
# IoU of Image 420 = tf.Tensor(0.9182841542316467, shape=(), dtype=float64)
# IoU of Image 421 = tf.Tensor(0.8886019918849133, shape=(), dtype=float64)
# IoU of Image 422 = tf.Tensor(0.7881465441972549, shape=(), dtype=float64)
# IoU of Image 423 = tf.Tensor(0.8152166205771821, shape=(), dtype=float64)
# IoU of Image 424 = tf.Tensor(0.8646526772793054, shape=(), dtype=float64)
# IoU of Image 425 = tf.Tensor(0.8439154391904059, shape=(), dtype=float64)
# IoU of Image 426 = tf.Tensor(0.8916023201684709, shape=(), dtype=float64)
# IoU of Image 427 = tf.Tensor(0.8014214341003448, shape=(), dtype=float64)
# IoU of Image 428 = tf.Tensor(0.681003348873859, shape=(), dtype=float64)
# IoU of Image 429 = tf.Tensor(0.4808092485549133, shape=(), dtype=float64)
# IoU of Image 430 = tf.Tensor(0.7033203967227253, shape=(), dtype=float64)
# IoU of Image 431 = tf.Tensor(0.39558971842887125, shape=(), dtype=float64)
# IoU of Image 432 = tf.Tensor(0.7249284632216798, shape=(), dtype=float64)
# IoU of Image 433 = tf.Tensor(0.7434535362822215, shape=(), dtype=float64)
# IoU of Image 434 = tf.Tensor(0.6487409029432601, shape=(), dtype=float64)
# IoU of Image 435 = tf.Tensor(0.8606220233799972, shape=(), dtype=float64)
# IoU of Image 436 = tf.Tensor(0.4022098843092744, shape=(), dtype=float64)
# IoU of Image 437 = tf.Tensor(0.8683434644924107, shape=(), dtype=float64)
# IoU of Image 438 = tf.Tensor(0.9504761904761905, shape=(), dtype=float64)
# IoU of Image 439 = tf.Tensor(0.8012212142358688, shape=(), dtype=float64)
# IoU of Image 440 = tf.Tensor(0.9463980231895077, shape=(), dtype=float64)
# IoU of Image 441 = tf.Tensor(0.8361126053433746, shape=(), dtype=float64)
# IoU of Image 442 = tf.Tensor(0.9720371297615837, shape=(), dtype=float64)
# IoU of Image 443 = tf.Tensor(0.4988729178254633, shape=(), dtype=float64)
# IoU of Image 444 = tf.Tensor(0.511728268208907, shape=(), dtype=float64)
# IoU of Image 445 = tf.Tensor(0.9479531273778725, shape=(), dtype=float64)
# IoU of Image 446 = tf.Tensor(0.529510502200245, shape=(), dtype=float64)
# IoU of Image 447 = tf.Tensor(0.8658892128279884, shape=(), dtype=float64)
# IoU of Image 448 = tf.Tensor(0.7541359821887309, shape=(), dtype=float64)
# IoU of Image 449 = tf.Tensor(0.8499856135807797, shape=(), dtype=float64)
# IoU of Image 450 = tf.Tensor(0.7709135516407128, shape=(), dtype=float64)
# IoU of Image 451 = tf.Tensor(0.7575175065220376, shape=(), dtype=float64)
# IoU of Image 452 = tf.Tensor(0.6887755102040817, shape=(), dtype=float64)
# IoU of Image 453 = tf.Tensor(0.76697956929873, shape=(), dtype=float64)
# IoU of Image 454 = tf.Tensor(0.9963348539790229, shape=(), dtype=float64)
# IoU of Image 455 = tf.Tensor(0.25, shape=(), dtype=float64)
# IoU of Image 456 = tf.Tensor(0.6047641435511675, shape=(), dtype=float64)
# IoU of Image 457 = tf.Tensor(0.8379581433750942, shape=(), dtype=float64)
# IoU of Image 458 = tf.Tensor(0.41237483103914374, shape=(), dtype=float64)
# IoU of Image 459 = tf.Tensor(0.5071768094223429, shape=(), dtype=float64)
# IoU of Image 460 = tf.Tensor(0.913804059357829, shape=(), dtype=float64)
# IoU of Image 461 = tf.Tensor(0.9762998417416142, shape=(), dtype=float64)
# IoU of Image 462 = tf.Tensor(0.6496971259182884, shape=(), dtype=float64)
# IoU of Image 463 = tf.Tensor(0.93607133411418, shape=(), dtype=float64)
# IoU of Image 464 = tf.Tensor(0.9236549443943493, shape=(), dtype=float64)
# IoU of Image 465 = tf.Tensor(0.7192169504046204, shape=(), dtype=float64)
# IoU of Image 466 = tf.Tensor(0.7545213722732773, shape=(), dtype=float64)
# IoU of Image 467 = tf.Tensor(0.9010136264062674, shape=(), dtype=float64)
# IoU of Image 468 = tf.Tensor(0.9649984648449493, shape=(), dtype=float64)
# IoU of Image 469 = tf.Tensor(0.8851251840942562, shape=(), dtype=float64)
# IoU of Image 470 = tf.Tensor(0.9587388831634795, shape=(), dtype=float64)
# IoU of Image 471 = tf.Tensor(0.9771393265369169, shape=(), dtype=float64)
# IoU of Image 472 = tf.Tensor(0.6949713642533187, shape=(), dtype=float64)
# IoU of Image 473 = tf.Tensor(0.7833507488679903, shape=(), dtype=float64)
# IoU of Image 474 = tf.Tensor(0.7647869846959878, shape=(), dtype=float64)
# IoU of Image 475 = tf.Tensor(0.49751389295115533, shape=(), dtype=float64)
# IoU of Image 476 = tf.Tensor(0.9702518040841395, shape=(), dtype=float64)
# IoU of Image 477 = tf.Tensor(0.8019286267333005, shape=(), dtype=float64)
# IoU of Image 478 = tf.Tensor(0.9879635022325762, shape=(), dtype=float64)
# IoU of Image 479 = tf.Tensor(0.8869315250239552, shape=(), dtype=float64)
# IoU of Image 480 = tf.Tensor(1.0, shape=(), dtype=float64)
# IoU of Image 481 = tf.Tensor(0.6981567580044185, shape=(), dtype=float64)
# IoU of Image 482 = tf.Tensor(0.6464081291401377, shape=(), dtype=float64)
# IoU of Image 483 = tf.Tensor(0.9617519813162831, shape=(), dtype=float64)
# IoU of Image 484 = tf.Tensor(0.7860765170593714, shape=(), dtype=float64)
# IoU of Image 485 = tf.Tensor(0.4175017994573944, shape=(), dtype=float64)
# IoU of Image 486 = tf.Tensor(0.7186235494766411, shape=(), dtype=float64)
# IoU of Image 487 = tf.Tensor(0.9836503816202394, shape=(), dtype=float64)
# IoU of Image 488 = tf.Tensor(0.60556439287608, shape=(), dtype=float64)
# IoU of Image 489 = tf.Tensor(0.9311862748786636, shape=(), dtype=float64)
# IoU of Image 490 = tf.Tensor(0.8691588785046729, shape=(), dtype=float64)
# IoU of Image 491 = tf.Tensor(0.8035984648427872, shape=(), dtype=float64)
# IoU of Image 492 = tf.Tensor(0.644600758013747, shape=(), dtype=float64)
# IoU of Image 493 = tf.Tensor(0.727297242634666, shape=(), dtype=float64)
# IoU of Image 494 = tf.Tensor(0.8499333597492885, shape=(), dtype=float64)
# IoU of Image 495 = tf.Tensor(0.8509815263367195, shape=(), dtype=float64)
# IoU of Image 496 = tf.Tensor(0.9558528933741542, shape=(), dtype=float64)
# IoU of Image 497 = tf.Tensor(0.8790369935408103, shape=(), dtype=float64)
# IoU of Image 498 = tf.Tensor(0.6835459686965671, shape=(), dtype=float64)
# IoU of Image 499 = tf.Tensor(0.8066974840326052, shape=(), dtype=float64)
# IoU of Image 500 = tf.Tensor(0.8842233099032127, shape=(), dtype=float64)
# IoU of Image 501 = tf.Tensor(0.6597510373443983, shape=(), dtype=float64)
# IoU of Image 502 = tf.Tensor(0.5241724220052394, shape=(), dtype=float64)
# IoU of Image 503 = tf.Tensor(0.5801981420326533, shape=(), dtype=float64)
# IoU of Image 504 = tf.Tensor(0.5460337590965365, shape=(), dtype=float64)
# IoU of Image 505 = tf.Tensor(0.6930657054991568, shape=(), dtype=float64)
# IoU of Image 506 = tf.Tensor(0.9879635022325762, shape=(), dtype=float64)
# IoU of Image 507 = tf.Tensor(0.8117480537862704, shape=(), dtype=float64)
# IoU of Image 508 = tf.Tensor(0.7448489126415919, shape=(), dtype=float64)
# IoU of Image 509 = tf.Tensor(0.7366861913418165, shape=(), dtype=float64)
# IoU of Image 510 = tf.Tensor(0.7395463610857587, shape=(), dtype=float64)
# IoU of Image 511 = tf.Tensor(0.8599920078468413, shape=(), dtype=float64)
# IoU of Image 512 = tf.Tensor(0.896384066844342, shape=(), dtype=float64)
# IoU of Image 513 = tf.Tensor(0.8701146906275111, shape=(), dtype=float64)
# IoU of Image 514 = tf.Tensor(0.7763591576171808, shape=(), dtype=float64)
# IoU of Image 515 = tf.Tensor(0.5911492323948039, shape=(), dtype=float64)
# IoU of Image 516 = tf.Tensor(0.8090594304289449, shape=(), dtype=float64)
# IoU of Image 517 = tf.Tensor(0.9462806777600486, shape=(), dtype=float64)
# IoU of Image 518 = tf.Tensor(0.5608328506539036, shape=(), dtype=float64)
# IoU of Image 519 = tf.Tensor(0.8856806128461991, shape=(), dtype=float64)
# IoU of Image 520 = tf.Tensor(0.7048481619605754, shape=(), dtype=float64)
# IoU of Image 521 = tf.Tensor(0.9645460824188473, shape=(), dtype=float64)
# IoU of Image 522 = tf.Tensor(0.6703640871721258, shape=(), dtype=float64)
# IoU of Image 523 = tf.Tensor(0.7260560293968917, shape=(), dtype=float64)
# IoU of Image 524 = tf.Tensor(0.8573497990077138, shape=(), dtype=float64)
# IoU of Image 525 = tf.Tensor(0.8997439798152203, shape=(), dtype=float64)
# IoU of Image 526 = tf.Tensor(0.9201200075004687, shape=(), dtype=float64)
# IoU of Image 527 = tf.Tensor(0.5803967879074161, shape=(), dtype=float64)
# IoU of Image 528 = tf.Tensor(0.7616852966466036, shape=(), dtype=float64)
# IoU of Image 529 = tf.Tensor(0.8907640607112522, shape=(), dtype=float64)
# IoU of Image 530 = tf.Tensor(0.9655265077354217, shape=(), dtype=float64)
# IoU of Image 531 = tf.Tensor(0.7567938512215208, shape=(), dtype=float64)
# IoU of Image 532 = tf.Tensor(0.9562144194398808, shape=(), dtype=float64)
# IoU of Image 533 = tf.Tensor(0.8351254480286738, shape=(), dtype=float64)
# IoU of Image 534 = tf.Tensor(0.837232668293383, shape=(), dtype=float64)
# IoU of Image 535 = tf.Tensor(0.7117368089410673, shape=(), dtype=float64)
# IoU of Image 536 = tf.Tensor(0.7258553340517241, shape=(), dtype=float64)
# IoU of Image 537 = tf.Tensor(0.5771973489191532, shape=(), dtype=float64)
# IoU of Image 538 = tf.Tensor(0.9595835884874464, shape=(), dtype=float64)
# IoU of Image 539 = tf.Tensor(0.9216333883801231, shape=(), dtype=float64)
# IoU of Image 540 = tf.Tensor(0.8831144948324691, shape=(), dtype=float64)
# IoU of Image 541 = tf.Tensor(0.8132016006232515, shape=(), dtype=float64)
# IoU of Image 542 = tf.Tensor(0.8819378078365067, shape=(), dtype=float64)
# IoU of Image 543 = tf.Tensor(0.7215292021115631, shape=(), dtype=float64)
# IoU of Image 544 = tf.Tensor(0.8967880561627088, shape=(), dtype=float64)
# IoU of Image 545 = tf.Tensor(0.9292362183955688, shape=(), dtype=float64)
# IoU of Image 546 = tf.Tensor(0.6331217505023763, shape=(), dtype=float64)
# IoU of Image 547 = tf.Tensor(0.8629669931084513, shape=(), dtype=float64)
# IoU of Image 548 = tf.Tensor(0.7198996655518395, shape=(), dtype=float64)
# IoU of Image 549 = tf.Tensor(0.5526443474041728, shape=(), dtype=float64)
# IoU of Image 550 = tf.Tensor(0.9747753307362981, shape=(), dtype=float64)
# IoU of Image 551 = tf.Tensor(0.6105693614344133, shape=(), dtype=float64)
# IoU of Image 552 = tf.Tensor(0.5602145294978059, shape=(), dtype=float64)
# IoU of Image 553 = tf.Tensor(0.8520528124434799, shape=(), dtype=float64)
# IoU of Image 554 = tf.Tensor(0.6881217471506687, shape=(), dtype=float64)
# IoU of Image 555 = tf.Tensor(0.9173875594502491, shape=(), dtype=float64)
# IoU of Image 556 = tf.Tensor(0.9362402148016489, shape=(), dtype=float64)
# IoU of Image 557 = tf.Tensor(0.8884639429264884, shape=(), dtype=float64)
# IoU of Image 558 = tf.Tensor(0.9742423073956967, shape=(), dtype=float64)
# IoU of Image 559 = tf.Tensor(0.662391636092081, shape=(), dtype=float64)
# IoU of Image 560 = tf.Tensor(0.9891219891219891, shape=(), dtype=float64)
# IoU of Image 561 = tf.Tensor(0.9853425879250843, shape=(), dtype=float64)
# IoU of Image 562 = tf.Tensor(0.8810240963855421, shape=(), dtype=float64)
# IoU of Image 563 = tf.Tensor(0.6500350921967715, shape=(), dtype=float64)
# IoU of Image 564 = tf.Tensor(0.8912505996531237, shape=(), dtype=float64)
# IoU of Image 565 = tf.Tensor(0.8758014288331196, shape=(), dtype=float64)
# IoU of Image 566 = tf.Tensor(0.6190671936758894, shape=(), dtype=float64)
# IoU of Image 567 = tf.Tensor(0.9515169995426132, shape=(), dtype=float64)
# IoU of Image 568 = tf.Tensor(0.47247427768708, shape=(), dtype=float64)
# IoU of Image 569 = tf.Tensor(0.7488130614475527, shape=(), dtype=float64)
# IoU of Image 570 = tf.Tensor(0.6625526401036606, shape=(), dtype=float64)
# IoU of Image 571 = tf.Tensor(0.6715092553295681, shape=(), dtype=float64)
# IoU of Image 572 = tf.Tensor(0.9769103054171976, shape=(), dtype=float64)
# IoU of Image 573 = tf.Tensor(0.9090942988180022, shape=(), dtype=float64)
# IoU of Image 574 = tf.Tensor(0.93280483201208, shape=(), dtype=float64)
# IoU of Image 575 = tf.Tensor(0.8863753592218702, shape=(), dtype=float64)
# IoU of Image 576 = tf.Tensor(0.9806576402321083, shape=(), dtype=float64)
# IoU of Image 577 = tf.Tensor(0.5389631855747559, shape=(), dtype=float64)
# IoU of Image 578 = tf.Tensor(0.39721604122400495, shape=(), dtype=float64)
# IoU of Image 579 = tf.Tensor(0.4549174504844989, shape=(), dtype=float64)
# IoU of Image 580 = tf.Tensor(0.8281143999714358, shape=(), dtype=float64)
# IoU of Image 581 = tf.Tensor(0.9705191856213679, shape=(), dtype=float64)
# IoU of Image 582 = tf.Tensor(0.7776543295604472, shape=(), dtype=float64)
# IoU of Image 583 = tf.Tensor(0.9299996262660238, shape=(), dtype=float64)
# IoU of Image 584 = tf.Tensor(0.7040537841975637, shape=(), dtype=float64)
# IoU of Image 585 = tf.Tensor(0.9671955238752203, shape=(), dtype=float64)
# IoU of Image 586 = tf.Tensor(0.9504018894518305, shape=(), dtype=float64)
# IoU of Image 587 = tf.Tensor(0.9320025659409079, shape=(), dtype=float64)
# IoU of Image 588 = tf.Tensor(0.6963789222825367, shape=(), dtype=float64)
# IoU of Image 589 = tf.Tensor(0.7133353391502023, shape=(), dtype=float64)
# IoU of Image 590 = tf.Tensor(0.7316645891587777, shape=(), dtype=float64)
# IoU of Image 591 = tf.Tensor(0.2960751713018944, shape=(), dtype=float64)
# IoU of Image 592 = tf.Tensor(0.5634210009262638, shape=(), dtype=float64)
# IoU of Image 593 = tf.Tensor(0.9235699827573282, shape=(), dtype=float64)
# IoU of Image 594 = tf.Tensor(0.6236630593000443, shape=(), dtype=float64)
# IoU of Image 595 = tf.Tensor(0.802245767186455, shape=(), dtype=float64)
# IoU of Image 596 = tf.Tensor(0.9445327881266091, shape=(), dtype=float64)
# IoU of Image 597 = tf.Tensor(0.7028636046163568, shape=(), dtype=float64)
# IoU of Image 598 = tf.Tensor(0.8021188976100806, shape=(), dtype=float64)
# IoU of Image 599 = tf.Tensor(0.7185244856174269, shape=(), dtype=float64)
# IoU of Image 600 = tf.Tensor(0.935581430515651, shape=(), dtype=float64)
# IoU of Image 601 = tf.Tensor(0.8026463963963963, shape=(), dtype=float64)
# IoU of Image 602 = tf.Tensor(0.5810195790952687, shape=(), dtype=float64)
# IoU of Image 603 = tf.Tensor(0.8238164784668542, shape=(), dtype=float64)
# IoU of Image 604 = tf.Tensor(0.8731662703493689, shape=(), dtype=float64)
# IoU of Image 605 = tf.Tensor(0.8775899372914299, shape=(), dtype=float64)
# IoU of Image 606 = tf.Tensor(0.7951689604131893, shape=(), dtype=float64)
# IoU of Image 607 = tf.Tensor(0.6619599441685331, shape=(), dtype=float64)
# IoU of Image 608 = tf.Tensor(0.9340460091413894, shape=(), dtype=float64)
# IoU of Image 609 = tf.Tensor(0.7241796664873588, shape=(), dtype=float64)
# IoU of Image 610 = tf.Tensor(0.2792816346231196, shape=(), dtype=float64)
# IoU of Image 611 = tf.Tensor(0.9803512029086409, shape=(), dtype=float64)
# IoU of Image 612 = tf.Tensor(0.7617998101179981, shape=(), dtype=float64)
# IoU of Image 613 = tf.Tensor(0.8029438692865695, shape=(), dtype=float64)
# IoU of Image 614 = tf.Tensor(0.45438018406999203, shape=(), dtype=float64)
# IoU of Image 615 = tf.Tensor(0.8857500644543479, shape=(), dtype=float64)
# IoU of Image 616 = tf.Tensor(0.5411609181588751, shape=(), dtype=float64)
# IoU of Image 617 = tf.Tensor(0.8181818181818182, shape=(), dtype=float64)
# IoU of Image 618 = tf.Tensor(0.6581384804715331, shape=(), dtype=float64)
# IoU of Image 619 = tf.Tensor(0.25, shape=(), dtype=float64)
# IoU of Image 620 = tf.Tensor(0.4109155026586219, shape=(), dtype=float64)
# IoU of Image 621 = tf.Tensor(0.9599586571220763, shape=(), dtype=float64)
# IoU of Image 622 = tf.Tensor(0.7573968559071875, shape=(), dtype=float64)
# IoU of Image 623 = tf.Tensor(0.8222586041214365, shape=(), dtype=float64)
# IoU of Image 624 = tf.Tensor(0.9149493211654262, shape=(), dtype=float64)
# IoU of Image 625 = tf.Tensor(0.6015014075695965, shape=(), dtype=float64)
# IoU of Image 626 = tf.Tensor(0.9770629802679847, shape=(), dtype=float64)
# IoU of Image 627 = tf.Tensor(0.798476430094, shape=(), dtype=float64)
# IoU of Image 628 = tf.Tensor(0.6044624110808186, shape=(), dtype=float64)
# IoU of Image 629 = tf.Tensor(0.38064933664113904, shape=(), dtype=float64)
# IoU of Image 630 = tf.Tensor(0.8406624991018179, shape=(), dtype=float64)
# IoU of Image 631 = tf.Tensor(0.9131609131609132, shape=(), dtype=float64)
# IoU of Image 632 = tf.Tensor(0.8153453410863707, shape=(), dtype=float64)
# IoU of Image 633 = tf.Tensor(0.26475964626253645, shape=(), dtype=float64)
# IoU of Image 634 = tf.Tensor(0.6793808008920665, shape=(), dtype=float64)
# IoU of Image 635 = tf.Tensor(0.8779342723004695, shape=(), dtype=float64)
# IoU of Image 636 = tf.Tensor(0.48878911993278723, shape=(), dtype=float64)
# IoU of Image 637 = tf.Tensor(0.7308992562542258, shape=(), dtype=float64)
# IoU of Image 638 = tf.Tensor(0.8656172569596269, shape=(), dtype=float64)
# IoU of Image 639 = tf.Tensor(0.9671879202366773, shape=(), dtype=float64)
# IoU of Image 640 = tf.Tensor(0.5321084445508408, shape=(), dtype=float64)
# IoU of Image 641 = tf.Tensor(0.4631398830742906, shape=(), dtype=float64)
# IoU of Image 642 = tf.Tensor(0.5232406086543033, shape=(), dtype=float64)
# IoU of Image 643 = tf.Tensor(0.7407268894706422, shape=(), dtype=float64)
# IoU of Image 644 = tf.Tensor(0.8946121965660154, shape=(), dtype=float64)
# IoU of Image 645 = tf.Tensor(0.8560812035526554, shape=(), dtype=float64)
# IoU of Image 646 = tf.Tensor(0.8186338933683799, shape=(), dtype=float64)
# IoU of Image 647 = tf.Tensor(0.8572672204287425, shape=(), dtype=float64)
# IoU of Image 648 = tf.Tensor(0.7594501718213058, shape=(), dtype=float64)
# IoU of Image 649 = tf.Tensor(0.5829644657567933, shape=(), dtype=float64)
# IoU of Image 650 = tf.Tensor(0.9858045999301865, shape=(), dtype=float64)
# IoU of Image 651 = tf.Tensor(0.8392786579013544, shape=(), dtype=float64)
# IoU of Image 652 = tf.Tensor(0.9992973690373956, shape=(), dtype=float64)
# ...
# IoU of Image 1365 = tf.Tensor(0.5001024440216596, shape=(), dtype=float64)
# IoU of Image 1366 = tf.Tensor(0.8505801134926085, shape=(), dtype=float64)
# IoU of Image 1367 = tf.Tensor(0.9322942219873948, shape=(), dtype=float64)
# IoU of Image 1368 = tf.Tensor(0.9407847440311778, shape=(), dtype=float64)
# IoU of Image 1369 = tf.Tensor(0.34178940196027047, shape=(), dtype=float64)
# IoU of Image 1370 = tf.Tensor(0.6313525569539589, shape=(), dtype=float64)
# IoU of Image 1371 = tf.Tensor(0.9210565811196157, shape=(), dtype=float64)
# IoU of Image 1372 = tf.Tensor(0.8696376811594203, shape=(), dtype=float64)
# IoU of Image 1373 = tf.Tensor(0.5894277490637864, shape=(), dtype=float64)
# IoU of Image 1374 = tf.Tensor(0.7925915552132203, shape=(), dtype=float64)
# IoU of Image 1375 = tf.Tensor(0.5345699326851159, shape=(), dtype=float64)
# IoU of Image 1376 = tf.Tensor(0.6326667091268072, shape=(), dtype=float64)
# IoU of Image 1377 = tf.Tensor(0.5430400191421906, shape=(), dtype=float64)
# IoU of Image 1378 = tf.Tensor(0.8371667444113531, shape=(), dtype=float64)
# IoU of Image 1379 = tf.Tensor(0.7362085918692571, shape=(), dtype=float64)
# IoU of Image 1380 = tf.Tensor(0.9614603685400146, shape=(), dtype=float64)
# IoU of Image 1381 = tf.Tensor(0.9593586162029774, shape=(), dtype=float64)
# IoU of Image 1382 = tf.Tensor(0.9749276759884281, shape=(), dtype=float64)
# IoU of Image 1383 = tf.Tensor(0.7366536161947251, shape=(), dtype=float64)
# IoU of Image 1384 = tf.Tensor(0.7480965550206562, shape=(), dtype=float64)
# IoU of Image 1385 = tf.Tensor(0.7350050830227042, shape=(), dtype=float64)
# IoU of Image 1386 = tf.Tensor(0.7458910182090978, shape=(), dtype=float64)
# IoU of Image 1387 = tf.Tensor(0.4269306710420201, shape=(), dtype=float64)
# IoU of Image 1388 = tf.Tensor(0.9530057979859627, shape=(), dtype=float64)
# IoU of Image 1389 = tf.Tensor(0.8465089440276976, shape=(), dtype=float64)
# IoU of Image 1390 = tf.Tensor(0.5727624546962344, shape=(), dtype=float64)
# IoU of Image 1391 = tf.Tensor(0.7509218792679596, shape=(), dtype=float64)
# IoU of Image 1392 = tf.Tensor(0.6792390947851754, shape=(), dtype=float64)
# IoU of Image 1393 = tf.Tensor(0.8174073548203891, shape=(), dtype=float64)
# IoU of Image 1394 = tf.Tensor(0.765821693395413, shape=(), dtype=float64)
# IoU of Image 1395 = tf.Tensor(0.8533835936097649, shape=(), dtype=float64)
# IoU of Image 1396 = tf.Tensor(0.8548036516446892, shape=(), dtype=float64)
# IoU of Image 1397 = tf.Tensor(0.6588220081463761, shape=(), dtype=float64)
# IoU of Image 1398 = tf.Tensor(0.3783972312397714, shape=(), dtype=float64)
# IoU of Image 1399 = tf.Tensor(0.8744279699798645, shape=(), dtype=float64)
# IoU of Image 1400 = tf.Tensor(0.8034519196900317, shape=(), dtype=float64)
# IoU of Image 1401 = tf.Tensor(0.8864448620168749, shape=(), dtype=float64)
# IoU of Image 1402 = tf.Tensor(0.9501790203397578, shape=(), dtype=float64)
# IoU of Image 1403 = tf.Tensor(0.8556775760211663, shape=(), dtype=float64)
# IoU of Image 1404 = tf.Tensor(0.9369727234895774, shape=(), dtype=float64)
# IoU of Image 1405 = tf.Tensor(0.953751049378005, shape=(), dtype=float64)
# IoU of Image 1406 = tf.Tensor(0.8975479665160382, shape=(), dtype=float64)
# IoU of Image 1407 = tf.Tensor(0.7865866424733059, shape=(), dtype=float64)
# IoU of Image 1408 = tf.Tensor(0.8709347365343857, shape=(), dtype=float64)
# IoU of Image 1409 = tf.Tensor(0.5774717318298056, shape=(), dtype=float64)
# IoU of Image 1410 = tf.Tensor(0.44145054451554955, shape=(), dtype=float64)
# IoU of Image 1411 = tf.Tensor(0.8519146786010755, shape=(), dtype=float64)
# IoU of Image 1412 = tf.Tensor(0.8393510875026918, shape=(), dtype=float64)
# IoU of Image 1413 = tf.Tensor(0.6743516792570065, shape=(), dtype=float64)
# IoU of Image 1414 = tf.Tensor(0.44939844302901627, shape=(), dtype=float64)
# IoU of Image 1415 = tf.Tensor(0.8781359393232205, shape=(), dtype=float64)
# IoU of Image 1416 = tf.Tensor(0.7974372476742145, shape=(), dtype=float64)
# IoU of Image 1417 = tf.Tensor(0.995245703596898, shape=(), dtype=float64)
# IoU of Image 1418 = tf.Tensor(0.8971050393759012, shape=(), dtype=float64)
# IoU of Image 1419 = tf.Tensor(0.8051687057081409, shape=(), dtype=float64)
# IoU of Image 1420 = tf.Tensor(0.6858144640692073, shape=(), dtype=float64)
# IoU of Image 1421 = tf.Tensor(0.7000929738345065, shape=(), dtype=float64)
# IoU of Image 1422 = tf.Tensor(0.7735601189241513, shape=(), dtype=float64)
# IoU of Image 1423 = tf.Tensor(0.8293554380448763, shape=(), dtype=float64)
# IoU of Image 1424 = tf.Tensor(0.928364280064781, shape=(), dtype=float64)
# IoU of Image 1425 = tf.Tensor(0.4219852246847748, shape=(), dtype=float64)
# IoU of Image 1426 = tf.Tensor(0.975994751263942, shape=(), dtype=float64)
# IoU of Image 1427 = tf.Tensor(0.9561396805990677, shape=(), dtype=float64)
# IoU of Image 1428 = tf.Tensor(0.8059108799550183, shape=(), dtype=float64)
# IoU of Image 1429 = tf.Tensor(0.8650056460131862, shape=(), dtype=float64)
# IoU of Image 1430 = tf.Tensor(0.6226666244097233, shape=(), dtype=float64)
# IoU of Image 1431 = tf.Tensor(0.8739477344264696, shape=(), dtype=float64)
# IoU of Image 1432 = tf.Tensor(0.8895777974608798, shape=(), dtype=float64)
# IoU of Image 1433 = tf.Tensor(0.9517401745892579, shape=(), dtype=float64)
# IoU of Image 1434 = tf.Tensor(0.9477946768060836, shape=(), dtype=float64)
# IoU of Image 1435 = tf.Tensor(0.7973110541650578, shape=(), dtype=float64)
# IoU of Image 1436 = tf.Tensor(0.668241504023981, shape=(), dtype=float64)
# IoU of Image 1437 = tf.Tensor(0.8660252204971208, shape=(), dtype=float64)
# IoU of Image 1438 = tf.Tensor(0.8965772707067714, shape=(), dtype=float64)
# IoU of Image 1439 = tf.Tensor(0.37361163277351506, shape=(), dtype=float64)
# IoU of Image 1440 = tf.Tensor(0.9557660720424768, shape=(), dtype=float64)
# IoU of Image 1441 = tf.Tensor(0.7517449021486247, shape=(), dtype=float64)
# IoU of Image 1442 = tf.Tensor(0.572047038594983, shape=(), dtype=float64)
# IoU of Image 1443 = tf.Tensor(0.46369353916523726, shape=(), dtype=float64)
# IoU of Image 1444 = tf.Tensor(0.4746968518678533, shape=(), dtype=float64)
# IoU of Image 1445 = tf.Tensor(0.8813845814654222, shape=(), dtype=float64)
# IoU of Image 1446 = tf.Tensor(0.8610061064262867, shape=(), dtype=float64)
# IoU of Image 1447 = tf.Tensor(0.3160941524494428, shape=(), dtype=float64)
# IoU of Image 1448 = tf.Tensor(0.7784570495675431, shape=(), dtype=float64)
# IoU of Image 1449 = tf.Tensor(0.9674902970449218, shape=(), dtype=float64)
# IoU of Image 1450 = tf.Tensor(0.8307648401826484, shape=(), dtype=float64)
# IoU of Image 1451 = tf.Tensor(0.8488426678221933, shape=(), dtype=float64)
# IoU of Image 1452 = tf.Tensor(0.6500209279113944, shape=(), dtype=float64)
# IoU of Image 1453 = tf.Tensor(0.8962962962962963, shape=(), dtype=float64)
# IoU of Image 1454 = tf.Tensor(0.8758701546127354, shape=(), dtype=float64)
# IoU of Image 1455 = tf.Tensor(0.7252417697206591, shape=(), dtype=float64)
# IoU of Image 1456 = tf.Tensor(0.785180551211205, shape=(), dtype=float64)
# IoU of Image 1457 = tf.Tensor(0.7144387891776052, shape=(), dtype=float64)
# IoU of Image 1458 = tf.Tensor(0.9367529126948101, shape=(), dtype=float64)
# IoU of Image 1459 = tf.Tensor(0.5443144567080689, shape=(), dtype=float64)
# IoU of Image 1460 = tf.Tensor(0.8592643694854943, shape=(), dtype=float64)
# IoU of Image 1461 = tf.Tensor(0.7808500278241514, shape=(), dtype=float64)
# IoU of Image 1462 = tf.Tensor(0.25, shape=(), dtype=float64)
# IoU of Image 1463 = tf.Tensor(0.7623571526917252, shape=(), dtype=float64)
# IoU of Image 1464 = tf.Tensor(0.8266143417766678, shape=(), dtype=float64)
# IoU of Image 1465 = tf.Tensor(0.8755952817056195, shape=(), dtype=float64)
# IoU of Image 1466 = tf.Tensor(0.8389483514115366, shape=(), dtype=float64)
# IoU of Image 1467 = tf.Tensor(0.8676674196604242, shape=(), dtype=float64)
# IoU of Image 1468 = tf.Tensor(0.944033109313893, shape=(), dtype=float64)
# IoU of Image 1469 = tf.Tensor(0.6412528794471462, shape=(), dtype=float64)
# IoU of Image 1470 = tf.Tensor(0.5881880024737167, shape=(), dtype=float64)
# IoU of Image 1471 = tf.Tensor(0.5538059778674114, shape=(), dtype=float64)
# IoU of Image 1472 = tf.Tensor(0.931565246915909, shape=(), dtype=float64)
# IoU of Image 1473 = tf.Tensor(0.5789262696968762, shape=(), dtype=float64)
# IoU of Image 1474 = tf.Tensor(0.9107329452157038, shape=(), dtype=float64)
# IoU of Image 1475 = tf.Tensor(0.4259455244248872, shape=(), dtype=float64)
# IoU of Image 1476 = tf.Tensor(0.7857765686582261, shape=(), dtype=float64)
# IoU of Image 1477 = tf.Tensor(0.8710443616166046, shape=(), dtype=float64)
# IoU of Image 1478 = tf.Tensor(0.6999610158164402, shape=(), dtype=float64)
# IoU of Image 1479 = tf.Tensor(0.8320750723206096, shape=(), dtype=float64)
# IoU of Image 1480 = tf.Tensor(0.7452363909056823, shape=(), dtype=float64)
# IoU of Image 1481 = tf.Tensor(0.5343253196012095, shape=(), dtype=float64)
# IoU of Image 1482 = tf.Tensor(0.8921735274554726, shape=(), dtype=float64)
# IoU of Image 1483 = tf.Tensor(0.7511541223540676, shape=(), dtype=float64)
# IoU of Image 1484 = tf.Tensor(0.43236816337949363, shape=(), dtype=float64)
# IoU of Image 1485 = tf.Tensor(0.877397951824607, shape=(), dtype=float64)
# IoU of Image 1486 = tf.Tensor(0.6885986609940306, shape=(), dtype=float64)
# IoU of Image 1487 = tf.Tensor(0.8062812576504739, shape=(), dtype=float64)
# IoU of Image 1488 = tf.Tensor(0.8671139960615564, shape=(), dtype=float64)
# IoU of Image 1489 = tf.Tensor(0.7540135870483659, shape=(), dtype=float64)
# IoU of Image 1490 = tf.Tensor(0.9525589199908474, shape=(), dtype=float64)
# IoU of Image 1491 = tf.Tensor(0.8594088741147564, shape=(), dtype=float64)
# IoU of Image 1492 = tf.Tensor(0.7962391243334269, shape=(), dtype=float64)
# IoU of Image 1493 = tf.Tensor(0.763541200371888, shape=(), dtype=float64)
# IoU of Image 1494 = tf.Tensor(0.947064192272589, shape=(), dtype=float64)
# IoU of Image 1495 = tf.Tensor(0.7249966750897726, shape=(), dtype=float64)
# IoU of Image 1496 = tf.Tensor(0.8564850067080024, shape=(), dtype=float64)
# IoU of Image 1497 = tf.Tensor(0.9020729623300394, shape=(), dtype=float64)
# IoU of Image 1498 = tf.Tensor(0.9100348587109693, shape=(), dtype=float64)
# IoU of Image 1499 = tf.Tensor(0.9373391857121235, shape=(), dtype=float64)
# IoU of Image 1500 = tf.Tensor(0.7102010822366224, shape=(), dtype=float64)
# IoU of Image 1501 = tf.Tensor(0.800661180277133, shape=(), dtype=float64)
# IoU of Image 1502 = tf.Tensor(0.8058055254035505, shape=(), dtype=float64)
# IoU of Image 1503 = tf.Tensor(0.8208328887940538, shape=(), dtype=float64)
# IoU of Image 1504 = tf.Tensor(0.8509815263367195, shape=(), dtype=float64)
# IoU of Image 1505 = tf.Tensor(0.6045126919460984, shape=(), dtype=float64)
# IoU of Image 1506 = tf.Tensor(0.9660548344981185, shape=(), dtype=float64)
# IoU of Image 1507 = tf.Tensor(0.7694319237518494, shape=(), dtype=float64)
# IoU of Image 1508 = tf.Tensor(0.7247187226301961, shape=(), dtype=float64)
# IoU of Image 1509 = tf.Tensor(0.8333512371540087, shape=(), dtype=float64)
# IoU of Image 1510 = tf.Tensor(0.9150925752758556, shape=(), dtype=float64)
# IoU of Image 1511 = tf.Tensor(0.8580345478298738, shape=(), dtype=float64)
# IoU of Image 1512 = tf.Tensor(0.7423855708694912, shape=(), dtype=float64)
# IoU of Image 1513 = tf.Tensor(0.7805599026256304, shape=(), dtype=float64)
# IoU of Image 1514 = tf.Tensor(0.7745121824420338, shape=(), dtype=float64)
# IoU of Image 1515 = tf.Tensor(0.8367713004484305, shape=(), dtype=float64)
# IoU of Image 1516 = tf.Tensor(0.8626489392618425, shape=(), dtype=float64)
# IoU of Image 1517 = tf.Tensor(0.5615945344191295, shape=(), dtype=float64)
# IoU of Image 1518 = tf.Tensor(0.69183491392129, shape=(), dtype=float64)
# IoU of Image 1519 = tf.Tensor(0.978743961352657, shape=(), dtype=float64)
# IoU of Image 1520 = tf.Tensor(0.9588338817047977, shape=(), dtype=float64)
# IoU of Image 1521 = tf.Tensor(0.9387330076867735, shape=(), dtype=float64)
# IoU of Image 1522 = tf.Tensor(0.25, shape=(), dtype=float64)
# IoU of Image 1523 = tf.Tensor(0.8332143876677134, shape=(), dtype=float64)
# IoU of Image 1524 = tf.Tensor(0.9314350367716387, shape=(), dtype=float64)
# IoU of Image 1525 = tf.Tensor(0.9746230089860773, shape=(), dtype=float64)
# IoU of Image 1526 = tf.Tensor(0.950624809509296, shape=(), dtype=float64)
# IoU of Image 1527 = tf.Tensor(0.4759722102107296, shape=(), dtype=float64)
# IoU of Image 1528 = tf.Tensor(0.9190404797601199, shape=(), dtype=float64)
# IoU of Image 1529 = tf.Tensor(0.8232319635353608, shape=(), dtype=float64)
# IoU of Image 1530 = tf.Tensor(0.5841939274009028, shape=(), dtype=float64)
# IoU of Image 1531 = tf.Tensor(0.7539652632660752, shape=(), dtype=float64)
# IoU of Image 1532 = tf.Tensor(0.9509458281208537, shape=(), dtype=float64)
# IoU of Image 1533 = tf.Tensor(0.919112410510139, shape=(), dtype=float64)
# IoU of Image 1534 = tf.Tensor(0.7658694603349645, shape=(), dtype=float64)
# IoU of Image 1535 = tf.Tensor(0.7314324278724481, shape=(), dtype=float64)
# IoU of Image 1536 = tf.Tensor(0.6954336540687102, shape=(), dtype=float64)
# IoU of Image 1537 = tf.Tensor(0.42650172740443554, shape=(), dtype=float64)
# IoU of Image 1538 = tf.Tensor(0.8176654359556944, shape=(), dtype=float64)
# IoU of Image 1539 = tf.Tensor(0.9923729473110748, shape=(), dtype=float64)
# IoU of Image 1540 = tf.Tensor(0.9879635022325762, shape=(), dtype=float64)
# IoU of Image 1541 = tf.Tensor(0.8855417249760624, shape=(), dtype=float64)
# IoU of Image 1542 = tf.Tensor(0.4794516611104725, shape=(), dtype=float64)
# IoU of Image 1543 = tf.Tensor(0.9235826727279558, shape=(), dtype=float64)
# IoU of Image 1544 = tf.Tensor(0.8897172805787259, shape=(), dtype=float64)
# IoU of Image 1545 = tf.Tensor(0.9304000301625005, shape=(), dtype=float64)
# IoU of Image 1546 = tf.Tensor(0.90653509588531, shape=(), dtype=float64)
# IoU of Image 1547 = tf.Tensor(0.23261942408126107, shape=(), dtype=float64)
# IoU of Image 1548 = tf.Tensor(0.7710134901418194, shape=(), dtype=float64)
# IoU of Image 1549 = tf.Tensor(0.7081470607860145, shape=(), dtype=float64)
# IoU of Image 1550 = tf.Tensor(0.6147867010778807, shape=(), dtype=float64)
# IoU of Image 1551 = tf.Tensor(0.6922084623323014, shape=(), dtype=float64)
# IoU of Image 1552 = tf.Tensor(0.9678683988008302, shape=(), dtype=float64)
# IoU of Image 1553 = tf.Tensor(0.86770696930016, shape=(), dtype=float64)
# IoU of Image 1554 = tf.Tensor(0.7840342869089515, shape=(), dtype=float64)
# IoU of Image 1555 = tf.Tensor(0.4186362250976698, shape=(), dtype=float64)
# IoU of Image 1556 = tf.Tensor(0.8965113390353835, shape=(), dtype=float64)
# IoU of Image 1557 = tf.Tensor(0.4117517302230678, shape=(), dtype=float64)
# IoU of Image 1558 = tf.Tensor(0.8383600713012478, shape=(), dtype=float64)
# IoU of Image 1559 = tf.Tensor(0.46627252252252255, shape=(), dtype=float64)
# IoU of Image 1560 = tf.Tensor(0.6774235822166891, shape=(), dtype=float64)
# IoU of Image 1561 = tf.Tensor(0.6422889402104183, shape=(), dtype=float64)
# IoU of Image 1562 = tf.Tensor(0.5336164612991985, shape=(), dtype=float64)
# IoU of Image 1563 = tf.Tensor(0.11365852601469217, shape=(), dtype=float64)
# IoU of Image 1564 = tf.Tensor(0.7613264990195742, shape=(), dtype=float64)
# IoU of Image 1565 = tf.Tensor(0.2731567822951635, shape=(), dtype=float64)
# IoU of Image 1566 = tf.Tensor(0.35535789919525623, shape=(), dtype=float64)
# IoU of Image 1567 = tf.Tensor(0.19238108535790746, shape=(), dtype=float64)
# IoU of Image 1568 = tf.Tensor(0.2257742495186937, shape=(), dtype=float64)
# IoU of Image 1569 = tf.Tensor(0.7897091722595079, shape=(), dtype=float64)
# IoU of Image 1570 = tf.Tensor(0.9179607492645142, shape=(), dtype=float64)
# IoU of Image 1571 = tf.Tensor(0.6419202770740468, shape=(), dtype=float64)
# IoU of Image 1572 = tf.Tensor(0.4634006916854832, shape=(), dtype=float64)
# IoU of Image 1573 = tf.Tensor(0.4058981822175847, shape=(), dtype=float64)
# IoU of Image 1574 = tf.Tensor(0.49105946764517444, shape=(), dtype=float64)
# IoU of Image 1575 = tf.Tensor(0.3726173561030535, shape=(), dtype=float64)
# IoU of Image 1576 = tf.Tensor(0.5535866003155723, shape=(), dtype=float64)
#
#
#  Mean intersection over Union is tf.Tensor(77.19081293818559, shape=(), dtype=float64)

# %% [markdown]
# ## **Further Training**
#
# If wished one can further train the model here by changing the file path to the place where the latest parameters are saved and further save the whole model in the desired directory by changing the path in the "trained_model.save" line.

# %%
checkpoint_filepath = '/content/drive/My Drive/weather_news/model_unet_processed/checkpoint'

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_filepath,
                                                               save_weights_only = True,
                                                               verbose = 1,
                                                               save_freq = 10
                                                               )

checkpoint_directory = os.path.dirname(checkpoint_filepath)

trained_model_ = model_construction(X,Y,'sgd','binary_crossentropy','acc')
latest = tf.train.latest_checkpoint(checkpoint_directory)
trained_model.load_weights(latest)
history = trained_model.fit(X,Y,epochs = 2000, validation_split = 0.01, callbacks = [model_checkpoint_callback], verbose = 2)
trained_model.save('/content/drive/My Drive/weather_news/model_unet_processed')
